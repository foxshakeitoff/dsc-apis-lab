# %% [markdown]
# # APIs - Cumulative Lab
#
#
# ## Introduction
#
# We've seen how the Yelp API works and how to create basic visualizations using Folium. It's time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API.
#
# ## Objectives
#
# You will be able to:
#
# * Practice using functions to organize your code
# * Use pagination to retrieve all results from an API query
# * Practice parsing data returned from an API query
# * Practice interpreting visualizations of a dataset
# * Create maps using Folium

# %% [markdown]
# ## Your Task: Query Yelp for All Businesses in a Category and Analyze the Results
#
# ![restaurant counter with pizza](images/restaurant_counter.jpg)
#
# Photo by <a href="https://unsplash.com/@jordanmadrid?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Jordan Madrid</a> on <a href="/s/photos/pizza-restaurant?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Overview
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. In this lab, you will write a query of businesses on Yelp, then use *pagination* to retrieve all possible results for that query. Then you will create a summary of your findings, including a Folium map of the geographic locations of those businesses.
#
# ### Technical Details
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the **API limits**. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a **maximum of 50 results per request** and defaults to 20. Furthermore, any search will be limited to a **total of 1000 results**. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retrieving 50 at a time. Processes such as these are often referred to as pagination.
#
# Also, be mindful of the **API** ***rate*** **limits**. You can only make **5000 requests per day** and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use `time.sleep(n)` to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a list of dictionaries (for further exploration) and create a map using Folium to visualize the results geographically.
#
# ### Requirements
#
# #### 1. Make the Initial Request
#
# Start by filling in your API key to make the initial request to the business search API. Investigate the structure of the response you get back and start figuring out how you will extract the relevant information.
#
# #### 2. Add Pagination
#
# Using loops and functions, collect the maximum number of results for your query from the API.
#
# #### 3. Perform Exploratory Analysis
#
# Interpret visualizations related to the price range, average rating, and number of reviews for all query results.
#
# #### 4. Create a Folium Map
#
# Using latitude and longitude data, plot the query results on an interactive map.

# %% [markdown]
# ## 1. Make the Initial Request
#
# ### Querying
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you but make the request below.
#
# Use the `requests` library ([documentation here](https://requests.readthedocs.io/en/master/user/quickstart/#make-a-request)).
#
# You'll also need an API key from Yelp. If you haven't done this already, go to the Yelp [Manage App page](https://www.yelp.com/developers/v3/manage_app) and create a new app (after making an account if you haven't already).

# %%
# Replace None with appropriate code

# Import the requests library
import requests
import json

# Get this from the "Manage App" page. Make sure you set them
# back to None before pushing this to GitHub, since otherwise
# your credentials will be compromised
def get_key(path):
    with open(path) as f:
        return json.load(f)
key = get_key('/Users/shentaitao/.secret/yelp_api.json')  
api_key = key['api_key']

# These can be whatever you want! But the solution uses "pizza"
# and "New York NY" if you want to compare your work directly
term = 'pizza'
location = 'New York NY'

# Set up params for request
url = "https://api.yelp.com/v3/businesses/search"
headers = {
    "Authorization": "Bearer {}".format(api_key)
}
url_params = {
    "term": term.replace(" ", "+"),
    "location": location.replace(" ", "+")
}

# Make the request using requests.get, passing in
# url, headers=headers, and params=url_params
response = requests.get(url=url,headers=headers,params=url_params)

# Confirm we got a 200 response
response
# Out:
# <Response [200]>

# %%
# Run this cell without changes

# Get the response body in JSON format
response_json = response.json()
# View the keys
response_json.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# ### Extracting Data
#
# Now, retrieve the value associated with the `'businesses'` key, and inspect its contents.

# %%
# Replace None with appropriate code

# Retrieve the value from response_json
businesses = response_json['businesses']

# View the first 2 records
businesses[:2]
# Out:
# [{'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I4gm7i1zoamgAk1hmOKbKw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=RG5abEkmIeuzqiCEhXNTGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RG5abEkmIeuzqiCEhXNTGA',
#   'review_count': 4724,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 2209.3116178604555},
#  {'id': 'ysqgdbSrezXgVwER2kQWKA',
#   'alias': 'julianas-brooklyn-3',
#   'name': "Juliana's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NVoLFle5H-SHNN6piAKIYw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=RG5abEkmIeuzqiCEhXNTGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RG5abEkmIeuzqiCEhXNTGA',
#   'review_count': 2601,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70274718768062,
#    'longitude': -73.99343490196397},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'phone': '+17185966700',
#   'display_phone': '(718) 596-6700',
#   'distance': 1289.8572856708206}]

# %% [markdown]
# ### Preparing Data
#
# Write a function `prepare_data` that takes in a list of dictionaries like `businesses` and returns a copy that has been prepared for analysis:
#
# 1. The `coordinates` key-value pair has been converted into two separate key-value pairs, `latitude` and `longitude`
# 2. All other key-value pairs except for `name`, `review_count`, `rating`, and `price` have been dropped
# 3. All dictionaries missing one of the relevant keys or containing null values have been dropped
#
# In other words, the final keys for each dictionary should be `name`, `review_count`, `rating`, `price`, `latitude`, and `longitude`.
#
# Complete the function in the cell below:

# %%
# Replace None with appropriate code

def prepare_data(data_list):
    """
    This function takes in a list of dictionaries and prepares it
    for analysis
    """
    
    # Make a new list to hold results
    results = []
    
    for business_data in data_list:
    
        # Make a new dictionary to hold prepared data for this business
        prepared_data = {}
        
        # Extract name, review_count, rating, and price key-value pairs
        # from business_data and add to prepared_data
        # If a key is not present in business_data, add it to prepared_data
        # with an associated value of None
        for key in ('name','review_count','rating','price'):
            prepared_data[key] = business_data.get(key,None)
####.get(key,none) get value() 
        # Parse and add latitude and longitude columns
        prepared_data['latitude']=business_data['coordinates']['latitude']
        prepared_data['longitude']=business_data['coordinates']['longitude']
        
        # Add to list if all values are present
        if all(prepared_data.values()):
            results.append(prepared_data)
#####all() check all items are true    
    return results
    
# Test out function
prepared_businesses = prepare_data(businesses)
prepared_businesses[:5]
# Out:
# [{'name': 'Prince Street Pizza',
#   'review_count': 4724,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72308755605564,
#   'longitude': -73.99453001177575},
#  {'name': "Juliana's",
#   'review_count': 2601,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70274718768062,
#   'longitude': -73.99343490196397},
#  {'name': "L'industrie Pizzeria",
#   'review_count': 859,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.71162,
#   'longitude': -73.95783},
#  {'name': 'Rubirosa',
#   'review_count': 2889,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.722766,
#   'longitude': -73.996233},
#  {'name': "Joe's Pizza",
#   'review_count': 2957,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73060076,
#   'longitude': -74.00215997}]

# %% [markdown]
# Check that your function created the correct keys:

# %%
# Run this cell without changes

assert sorted(list(prepared_businesses[0].keys())) == ['latitude', 'longitude', 'name', 'price', 'rating', 'review_count']

# %% [markdown]
# The following code will differ depending on your query, but we expect there to be 20 businesses in the original list, and potentially fewer in the prepared list (if any of them were missing data):

# %%
# Run this cell without changes
print("Original:", len(businesses))
print("Prepared:", len(prepared_businesses))
# Out:
# Original: 20
# Prepared: 18

# %% [markdown]
# Great! We will reuse this function once we have retrieved the full dataset.

# %% [markdown]
# ## 2. Add Pagination
#
# Now that you are able to extract information from one page of the response, let's figure out how to request as many pages as possible.
#
# ### Determining the Total
#
# Depending on the number of total results for your query, you will either retrieve all of the results, or just the first 1000 (if there are more than 1000 total).
#
# We can find the total number of results using the `"total"` key:

# %%
# Run this cell without changes
response_json["total"]
# Out:
# 14700

# %% [markdown]
# (This is specific to the implementation of the Yelp API. Some APIs will just tell you that there are more pages, or will tell you the number of pages total, rather than the total number of results. If you're not sure, always check the documentation.)
#
# In the cell below, assign the variable `total` to either the value shown above (if it is less than 1000), or 1000.

# %%
# Replace None with appropriate code
total = 1000

# %% [markdown]
# ### Calculating the Offsets
#
# The documentation states in the parameters section:
#
# > **Name**: `limit`, **Type:** int, **Description:** Optional. Number of business results to return. By default, it will return 20. Maximum is 50.
#
# > **Name**: `offset`, **Type:** int, **Description:** Optional. Offset the list of returned business results by this amount.
#
# So, to get the most results with the fewest API calls we want to set a limit of 50 every time. If, say, we wanted to get 210 total results, that would mean:
#
# 1. Offset of `0` (first 50 records)
# 2. Offset of `50` (second 50 records)
# 3. Offset of `100` (third 50 records)
# 4. Offset of `150` (fourth 50 records)
# 5. Offset of `200` (final 10 records)
#
# In the cell below, create a function `get_offsets` that takes in a total and returns a list of offsets for that total. You can assume that there is a limit of 50 every time.
#
# *Hint: you can use `range` ([documentation here](https://docs.python.org/3.3/library/stdtypes.html?highlight=range#range)) to do this in one line of code. Just make the returned result is a list.*

# %%
# Replace None with appropriate code
def get_offsets(total):
    """
    Get a list of offsets needed to get all pages
    of data up until the total
    """
    return list(range(0,total,50))

# %% [markdown]
# Check that your function works below:

# %%
# Run this cell without changes

assert get_offsets(200) == [0, 50, 100, 150]
assert get_offsets(210) == [0, 50, 100, 150, 200]

"""offset means balances. how much already done"""

# %% [markdown]
# ### Putting It All Together
#
# Recall that the following variable has already been declared for you:

# %%
# Run this cell without changes
url_params
# Out:
# {'term': 'pizza', 'location': 'New+York+NY'}

# %% [markdown]
# We'll go ahead and also specify that the limit should be 50 every time:

# %%
# Run this cell without changes
url_params["limit"] = 50

# %% [markdown]
# In order to modify the offset, you'll need to add it to `url_params` with the key `"offset"` and whatever value is needed.
#
# In the cell below, write code that:
#
# * Creates an empty list for the full prepared dataset
# * Loops over all of the offsets from `get_offsets` and makes an API call each time with the specified offset
# * Calls `prepare_data` to get a cleaned version of the result of each API call
# * Extends the full prepared dataset list with each query's prepared dataset

# %%
# Replace None with appropriate code

# Create an empty list for the full prepared dataset
full_dataset = []

for offset in get_offsets(total):
    # Add or update the "offset" key-value pair in url_params
    url_params['offset'] = offset
    
    # Make the query and get the response
    response = requests.get(url, headers=headers, params=url_params)
    
    # Get the response body in JSON format
    response_json = response.json()
    
    # Get the list of businesses from the response_json
    businesses = response_json['businesses']
    
    # Call the prepare_data function to get a list of processed data
    prepared_businesses = prepare_data(businesses)
    
    # Extend full_dataset with this list (don't append, or you'll get
    # a list of lists instead of a flat list)
    full_dataset.extend(prepared_businesses)

# Check the length of the full dataset. It will be up to `total`,
# potentially less if there were missing values
len(full_dataset)
# Out:
# 749

# %%
full_dataset
# Out:
# [{'name': "Juliana's",
#   'review_count': 2601,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70274718768062,
#   'longitude': -73.99343490196397},
#  {'name': "L'industrie Pizzeria",
#   'review_count': 859,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.71162,
#   'longitude': -73.95783},
#  {'name': 'Rubirosa',
#   'review_count': 2889,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.722766,
#   'longitude': -73.996233},
#  {'name': "Lombardi's Pizza",
#   'review_count': 6520,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7215934960083,
#   'longitude': -73.9955956044561},
#  {'name': "Joe's Pizza",
#   'review_count': 2957,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73060076,
#   'longitude': -74.00215997},
#  {'name': "Joe's Pizza",
#   'review_count': 1754,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7547,
#   'longitude': -73.98696},
#  {'name': "Joe's Pizza",
#   'review_count': 1037,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73331,
#   'longitude': -73.98763},
#  {'name': 'Lucali',
#   'review_count': 1926,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.681840746711224,
#   'longitude': -74.0003327},
#  {'name': "Scarr's Pizza",
#   'review_count': 691,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71534,
#   'longitude': -73.9914},
#  {'name': "John's of Bleecker Street",
#   'review_count': 2488,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73158,
#   'longitude': -74.00332},
#  {'name': "Paulie Gee's",
#   'review_count': 1330,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.729546,
#   'longitude': -73.958568},
#  {'name': "Grimaldi's Pizzeria",
#   'review_count': 4907,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7026459,
#   'longitude': -73.9932413},
#  {'name': 'Piz-zetta',
#   'review_count': 331,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69116658201196,
#   'longitude': -73.99065911521895},
#  {'name': "Joe's Pizza",
#   'review_count': 433,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7168952,
#   'longitude': -73.95892996733771},
#  {'name': 'Nolita Pizza',
#   'review_count': 182,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7208883,
#   'longitude': -73.9962404},
#  {'name': "Lil Frankie's",
#   'review_count': 1414,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.723625,
#   'longitude': -73.988555},
#  {'name': 'Front Street Pizza',
#   'review_count': 447,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70244,
#   'longitude': -73.98943},
#  {'name': 'Barano',
#   'review_count': 307,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.710372,
#   'longitude': -73.96794},
#  {'name': "Joe's Pizza",
#   'review_count': 422,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7101297729083,
#   'longitude': -74.0077206864953},
#  {'name': 'Sottocasa Pizzeria',
#   'review_count': 701,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.688285,
#   'longitude': -73.989006},
#  {'name': "Roberta's",
#   'review_count': 3223,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70493,
#   'longitude': -73.93399},
#  {'name': 'L & B Spumoni Gardens',
#   'review_count': 4495,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.594715,
#   'longitude': -73.981316},
#  {'name': 'Village Square Pizza',
#   'review_count': 259,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72748,
#   'longitude': -73.98268},
#  {'name': 'Marinara Pizza',
#   'review_count': 320,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7826,
#   'longitude': -73.95351},
#  {'name': "Ace's Pizza",
#   'review_count': 132,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71505,
#   'longitude': -73.958365},
#  {'name': 'Il Porto',
#   'review_count': 380,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6974427,
#   'longitude': -73.9675197},
#  {'name': 'Song E Napule',
#   'review_count': 665,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72813,
#   'longitude': -74.00188},
#  {'name': "Dellarocco's Brick Oven Pizza",
#   'review_count': 341,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6950309,
#   'longitude': -73.9961252},
#  {'name': "Adrienne's Pizzabar",
#   'review_count': 1817,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7043362,
#   'longitude': -74.0101733},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 670,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.76458,
#   'longitude': -73.98247},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 608,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6818695,
#   'longitude': -73.976181},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 4163,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7321124557704,
#   'longitude': -73.9839056828882},
#  {'name': "MAMA'S TOO!",
#   'review_count': 604,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.80084,
#   'longitude': -73.96766},
#  {'name': 'Cuts & Slices',
#   'review_count': 256,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6854737,
#   'longitude': -73.9203186},
#  {'name': 'Ops',
#   'review_count': 183,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70276,
#   'longitude': -73.9171},
#  {'name': 'Champion Pizza',
#   'review_count': 414,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7215270996094,
#   'longitude': -73.9970855712891},
#  {'name': "Paulie Gee's Slice Shop",
#   'review_count': 308,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72836,
#   'longitude': -73.9572},
#  {'name': "Patrizia's - Williamsburg",
#   'review_count': 783,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7109154314181,
#   'longitude': -73.9673637711639},
#  {'name': 'NY Pizza Suprema',
#   'review_count': 2400,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7502059936523,
#   'longitude': -73.9953231811523},
#  {'name': "Patrizia's - Williamsburg",
#   'review_count': 783,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7109154314181,
#   'longitude': -73.9673637711639},
#  {'name': "Brooklyn's Homeslice Pizzeria",
#   'review_count': 186,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.680702,
#   'longitude': -73.967455},
#  {'name': "Luigi's Pizzeria",
#   'review_count': 280,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6897,
#   'longitude': -73.965369},
#  {'name': "Tony's Pizzeria of Nassau Ave",
#   'review_count': 63,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.725290886426,
#   'longitude': -73.946226015687},
#  {'name': 'Da Andrea',
#   'review_count': 1783,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.736218,
#   'longitude': -73.99597},
#  {'name': 'My Pie Pizzeria Romana',
#   'review_count': 887,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7608512,
#   'longitude': -73.9694809},
#  {'name': 'Levante',
#   'review_count': 323,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74764,
#   'longitude': -73.94173},
#  {'name': 'Il Mattone',
#   'review_count': 105,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.720799,
#   'longitude': -74.0091255},
#  {'name': 'Goodfellas Pizzeria of LIC',
#   'review_count': 78,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75334,
#   'longitude': -73.93716},
#  {'name': "Louie's Pizza",
#   'review_count': 526,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.74600424769782,
#   'longitude': -73.88356062541311},
#  {'name': "Tony's Pizzeria & Restaurant",
#   'review_count': 354,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.699286,
#   'longitude': -73.918724},
#  {'name': 'Krispy Pizza ',
#   'review_count': 324,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.62236,
#   'longitude': -74.0055},
#  {'name': 'Siena Pizza & Cannoli',
#   'review_count': 90,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.708152,
#   'longitude': -74.013864},
#  {'name': 'Di Fara Pizza',
#   'review_count': 3940,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.625093,
#   'longitude': -73.961531},
#  {'name': 'Ribalta Pizza',
#   'review_count': 733,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7334346,
#   'longitude': -73.9916923},
#  {'name': 'Fornino',
#   'review_count': 291,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.692930215177675,
#   'longitude': -74.00165153160219},
#  {'name': 'Sofia Pizza Shoppe',
#   'review_count': 240,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75674,
#   'longitude': -73.96431},
#  {'name': 'Adoro Lei',
#   'review_count': 356,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.725612,
#   'longitude': -74.007916},
#  {'name': 'Lucia Pizza',
#   'review_count': 629,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.76032,
#   'longitude': -73.82813},
#  {'name': 'Stone Bridge Pizza & Salad',
#   'review_count': 318,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.75225,
#   'longitude': -73.98061},
#  {'name': "Louie & Ernie's Pizza",
#   'review_count': 371,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.838288,
#   'longitude': -73.828563},
#  {'name': "Joe & Pat's Pizzeria",
#   'review_count': 275,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72892,
#   'longitude': -73.98411},
#  {'name': 'Wheated',
#   'review_count': 371,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6465968960541,
#   'longitude': -73.9704950265688},
#  {'name': 'Barboncino Pizza & Bar',
#   'review_count': 1104,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.67206,
#   'longitude': -73.95717},
#  {'name': 'Lo Duca Pizza',
#   'review_count': 148,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6349400235262,
#   'longitude': -73.9625812061059},
#  {'name': 'Time Out Market New York',
#   'review_count': 444,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70342863348067,
#   'longitude': -73.99214637055226},
#  {'name': 'B Side Pizza & Wine Bar',
#   'review_count': 1267,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.76388,
#   'longitude': -73.98821},
#  {'name': 'Saraghina Pizzeria',
#   'review_count': 992,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6837407,
#   'longitude': -73.9353473},
#  {'name': 'Motorino Pizzeria Napoletana',
#   'review_count': 265,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7104799,
#   'longitude': -73.96351},
#  {'name': 'Pizza Barn',
#   'review_count': 496,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.92033366683442,
#   'longitude': -73.86751644723435},
#  {'name': 'Sottocasa Pizzeria - Harlem',
#   'review_count': 330,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.8055499,
#   'longitude': -73.94746},
#  {'name': "Angelo's Coal Oven Pizzeria",
#   'review_count': 1112,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76492,
#   'longitude': -73.97794},
#  {'name': 'Razza',
#   'review_count': 1150,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7177776,
#   'longitude': -74.0442612},
#  {'name': 'J & V Pizzeria',
#   'review_count': 271,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6199507795829,
#   'longitude': -73.9896828},
#  {'name': 'La Villa',
#   'review_count': 583,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6743319055498,
#   'longitude': -73.9816949398812},
#  {'name': "Giuseppina's",
#   'review_count': 347,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6603430973463,
#   'longitude': -73.9907741546631},
#  {'name': "Mike's Pizza",
#   'review_count': 147,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75214,
#   'longitude': -73.934339},
#  {'name': 'Luna Pizza',
#   'review_count': 99,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.713245675315,
#   'longitude': -73.998651104496},
#  {'name': "Fresco's Pizzeria",
#   'review_count': 242,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.8551130123675,
#   'longitude': -73.9372547647758},
#  {'name': 'Leuca',
#   'review_count': 411,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.722121,
#   'longitude': -73.956678},
#  {'name': "Joe & John's Pizzeria",
#   'review_count': 174,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7003933525757,
#   'longitude': -73.8993881901177},
#  {'name': 'Lions & Tigers & Squares Detroit Pizza',
#   'review_count': 532,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.74506,
#   'longitude': -73.99834},
#  {'name': 'Milkflower',
#   'review_count': 745,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7628961,
#   'longitude': -73.9207081},
#  {'name': 'Dough Vale',
#   'review_count': 101,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70933,
#   'longitude': -73.95407},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 924,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.797157,
#   'longitude': -73.93488},
#  {'name': "Arturo's",
#   'review_count': 758,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7273563342024,
#   'longitude': -74.0004944801331},
#  {'name': '&pizza - Astor Place',
#   'review_count': 211,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72981093692917,
#   'longitude': -73.9926904},
#  {'name': 'Loring Place',
#   'review_count': 524,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73293764919451,
#   'longitude': -73.99758608256435},
#  {'name': "Emmett's",
#   'review_count': 590,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.727303,
#   'longitude': -74.00243},
#  {'name': 'Fascati Pizza',
#   'review_count': 263,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6985,
#   'longitude': -73.99273},
#  {'name': 'SIMÒ PIZZA',
#   'review_count': 235,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7392597584612,
#   'longitude': -74.0088130692187},
#  {'name': "Carmine's Pizzeria",
#   'review_count': 516,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.714987,
#   'longitude': -73.94414},
#  {'name': 'La Lanterna Di Vittorio',
#   'review_count': 1620,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73069,
#   'longitude': -74.00015},
#  {'name': "Nick's Pizza",
#   'review_count': 581,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.78272735790179,
#   'longitude': -73.9478073},
#  {'name': 'Jentana Pizza Restaurant',
#   'review_count': 74,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6375122070312,
#   'longitude': -73.9994735717773},
#  {'name': 'Don Antonio',
#   'review_count': 1623,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.762711,
#   'longitude': -73.986708},
#  {'name': 'Roma Pizza',
#   'review_count': 378,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.77843,
#   'longitude': -73.94863},
#  {'name': 'Emmy Squared Pizza - East Village ',
#   'review_count': 349,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72598,
#   'longitude': -73.98672},
#  {'name': "Luna's Pizzeria & Restaurant",
#   'review_count': 9,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7603635173753,
#   'longitude': -74.0371671497532},
#  {'name': 'Sauce',
#   'review_count': 916,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7204716,
#   'longitude': -73.9893263},
#  {'name': 'Don Angie',
#   'review_count': 629,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73778,
#   'longitude': -74.00197},
#  {'name': 'Inatteso Pizzabar',
#   'review_count': 344,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7056571,
#   'longitude': -74.0172056},
#  {'name': 'Follia',
#   'review_count': 272,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7349243164062,
#   'longitude': -73.9855880737305},
#  {'name': 'Margherita NYC',
#   'review_count': 317,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7189865112305,
#   'longitude': -73.9969329833984},
#  {'name': "Luzzo's BK",
#   'review_count': 213,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.690706,
#   'longitude': -73.9952269},
#  {'name': 'Circa Brewing',
#   'review_count': 403,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.69165,
#   'longitude': -73.98603},
#  {'name': 'Leo',
#   'review_count': 79,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7125608,
#   'longitude': -73.9567886},
#  {'name': "Rosa's Pizza",
#   'review_count': 440,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72697,
#   'longitude': -73.89564},
#  {'name': 'Santa Panza',
#   'review_count': 219,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6947,
#   'longitude': -73.93068},
#  {'name': 'Pizza Palace',
#   'review_count': 142,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.8629818681867,
#   'longitude': -73.9256393909454},
#  {'name': 'GRUPPO NYCThinCrust Pizza',
#   'review_count': 272,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72474,
#   'longitude': -73.98161},
#  {'name': 'Ci Siamo',
#   'review_count': 225,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.75240549384363,
#   'longitude': -73.9982864846782},
#  {'name': 'Circa Brewing',
#   'review_count': 403,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.69165,
#   'longitude': -73.98603},
#  {'name': 'Leo',
#   'review_count': 79,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7125608,
#   'longitude': -73.9567886},
#  {'name': "Rosa's Pizza",
#   'review_count': 440,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72697,
#   'longitude': -73.89564},
#  {'name': 'Santa Panza',
#   'review_count': 219,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6947,
#   'longitude': -73.93068},
#  {'name': 'Pizza Palace',
#   'review_count': 142,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.8629818681867,
#   'longitude': -73.9256393909454},
#  {'name': 'Motorino',
#   'review_count': 1112,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73039,
#   'longitude': -73.98381},
#  {'name': 'Ci Siamo',
#   'review_count': 225,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.75240549384363,
#   'longitude': -73.9982864846782},
#  {'name': '&pizza - Wall St',
#   'review_count': 140,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7057647,
#   'longitude': -74.0085474},
#  {'name': "Lombardo's of Bay Ridge",
#   'review_count': 189,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.634741,
#   'longitude': -74.0284259},
#  {'name': 'Piacere',
#   'review_count': 710,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7196979,
#   'longitude': -73.9951175},
#  {'name': 'Famous Calabria',
#   'review_count': 97,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.711942,
#   'longitude': -73.999349},
#  {'name': 'Pizzette',
#   'review_count': 67,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70858,
#   'longitude': -73.94357},
#  {'name': 'Marta',
#   'review_count': 988,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7445882,
#   'longitude': -73.9847936},
#  {'name': 'New Park Pizza',
#   'review_count': 1010,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6627403949909,
#   'longitude': -73.8403776268684},
#  {'name': 'Trapizzino',
#   'review_count': 286,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72043,
#   'longitude': -73.98894},
#  {'name': 'Fumo Pizza-Bar-Pasta',
#   'review_count': 551,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.821427,
#   'longitude': -73.950638},
#  {'name': "Roey's",
#   'review_count': 168,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73596,
#   'longitude': -74.00093},
#  {'name': 'Tavola',
#   'review_count': 1218,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.755403,
#   'longitude': -73.994516},
#  {'name': "Natoli's",
#   'review_count': 325,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.79508,
#   'longitude': -74.06316},
#  {'name': "Freddie & Pepper's",
#   'review_count': 517,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.779999,
#   'longitude': -73.980301},
#  {'name': 'Paesano of Mulberry Street',
#   'review_count': 1317,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.718554,
#   'longitude': -73.997447},
#  {'name': 'Artistic Pizza',
#   'review_count': 106,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.73068,
#   'longitude': -74.00042},
#  {'name': 'Campania Coal Fired Pizza',
#   'review_count': 665,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6136093139648,
#   'longitude': -74.033332824707},
#  {'name': 'Eataly NYC Flatiron',
#   'review_count': 6021,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74200824886595,
#   'longitude': -73.98993910744127},
#  {'name': "Sam's",
#   'review_count': 236,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.685920715332,
#   'longitude': -73.9945220947266},
#  {'name': 'Sotto 13',
#   'review_count': 1029,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7372,
#   'longitude': -73.99919},
#  {'name': 'BRADO NYCThinCrust Pizza',
#   'review_count': 160,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6905570310882,
#   'longitude': -73.99494681265617},
#  {'name': "Nick's Pizza - Forest Hills",
#   'review_count': 959,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.71797254115706,
#   'longitude': -73.84048067055303},
#  {'name': 'Speedy Romeo',
#   'review_count': 660,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6875154792236,
#   'longitude': -73.959874469611},
#  {'name': 'Rosemary’s',
#   'review_count': 194,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.735097,
#   'longitude': -73.979074},
#  {'name': "Romeo's Pizza",
#   'review_count': 160,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7291074,
#   'longitude': -73.7808497},
#  {'name': 'Williamsburg Pizza',
#   'review_count': 271,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71822,
#   'longitude': -73.99123},
#  {'name': 'POSTO NYCThinCrust Pizza',
#   'review_count': 659,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73483,
#   'longitude': -73.98282},
#  {'name': 'POSTO NYCThinCrust Pizza',
#   'review_count': 659,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73483,
#   'longitude': -73.98282},
#  {'name': "G&J's Pizzeria",
#   'review_count': 70,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7903349463747,
#   'longitude': -73.946079551947},
#  {'name': 'Bono Trattoria',
#   'review_count': 354,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.8301996389829,
#   'longitude': -73.9473449424522},
#  {'name': 'K Pizza',
#   'review_count': 68,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.842018,
#   'longitude': -74.000809},
#  {'name': 'Numero 28 Ristorante Pizzeria Bar',
#   'review_count': 573,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73041,
#   'longitude': -73.98595},
#  {'name': 'DaVinci Pizzeria',
#   'review_count': 154,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.618881,
#   'longitude': -73.990798},
#  {'name': 'Xtra Cheese Pizza',
#   'review_count': 131,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7651362,
#   'longitude': -73.8182876},
#  {'name': 'Two Boots Pizza - West Village',
#   'review_count': 55,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.73314309005766,
#   'longitude': -74.0027964258894},
#  {'name': 'Emily',
#   'review_count': 899,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68351,
#   'longitude': -73.96643},
#  {'name': 'Peperino NYC Pizza',
#   'review_count': 99,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.77275912931571,
#   'longitude': -73.99077586611165},
#  {'name': "Joe's Pizza",
#   'review_count': 8,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.85392,
#   'longitude': -73.88413},
#  {'name': 'Osteria Brooklyn',
#   'review_count': 164,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.693154,
#   'longitude': -73.967177},
#  {'name': 'VEZZO NYCThinCrust Pizza',
#   'review_count': 1379,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.744435447210506,
#   'longitude': -73.9814189},
#  {'name': 'Salvatores of Soho',
#   'review_count': 334,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8875232,
#   'longitude': -73.90704},
#  {'name': 'Milano Pizzeria',
#   'review_count': 36,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7968348033007,
#   'longitude': -73.93813295643352},
#  {'name': 'Love & Dough',
#   'review_count': 245,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.702950557308085,
#   'longitude': -73.98748593042708},
#  {'name': "John's of Times Square",
#   'review_count': 2361,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75823,
#   'longitude': -73.98836},
#  {'name': "Lazzara's Pizza",
#   'review_count': 336,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.754057,
#   'longitude': -73.989497},
#  {'name': 'Parm',
#   'review_count': 409,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.714473491420726,
#   'longitude': -74.01609333303082},
#  {'name': 'Oath Pizza - New York',
#   'review_count': 259,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7664835,
#   'longitude': -73.9633564},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 294,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.70638449968762,
#   'longitude': -73.92288771165168},
#  {'name': "Rizzo's Fine Pizza",
#   'review_count': 650,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.76337,
#   'longitude': -73.915124},
#  {'name': 'Village Pizza',
#   'review_count': 155,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73927,
#   'longitude': -74.00321},
#  {'name': "Vic's",
#   'review_count': 560,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72693,
#   'longitude': -73.99319},
#  {'name': 'Emily - West Village',
#   'review_count': 920,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.729375015649076,
#   'longitude': -74.00386306706551},
#  {'name': 'Tufino Pizzeria Napoletana',
#   'review_count': 450,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.773986,
#   'longitude': -73.908126},
#  {'name': 'Krispy Pizza',
#   'review_count': 246,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.713375,
#   'longitude': -74.035044},
#  {'name': "Philomena's",
#   'review_count': 160,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743264,
#   'longitude': -73.922928},
#  {'name': "Sal & Carmine's Pizza",
#   'review_count': 392,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7983115,
#   'longitude': -73.9694405},
#  {'name': 'House of Pizza & Calzones',
#   'review_count': 171,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.683944,
#   'longitude': -74.00225},
#  {'name': "Monte's Brick Oven",
#   'review_count': 171,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.807312,
#   'longitude': -73.926788},
#  {'name': 'Champion Pizza',
#   'review_count': 162,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.719742,
#   'longitude': -73.9872791},
#  {'name': 'Pier 76',
#   'review_count': 252,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.640118,
#   'longitude': -74.0759269},
#  {'name': 'Emily - West Village',
#   'review_count': 920,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.729375015649076,
#   'longitude': -74.00386306706551},
#  {'name': "Saba's Pizza",
#   'review_count': 119,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.78329,
#   'longitude': -73.978},
#  {'name': 'Krispy Pizza',
#   'review_count': 246,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.713375,
#   'longitude': -74.035044},
#  {'name': "Philomena's",
#   'review_count': 160,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743264,
#   'longitude': -73.922928},
#  {'name': "Sal & Carmine's Pizza",
#   'review_count': 392,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7983115,
#   'longitude': -73.9694405},
#  {'name': 'House of Pizza & Calzones',
#   'review_count': 171,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.683944,
#   'longitude': -74.00225},
#  {'name': "Monte's Brick Oven",
#   'review_count': 171,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.807312,
#   'longitude': -73.926788},
#  {'name': 'Champion Pizza',
#   'review_count': 162,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.719742,
#   'longitude': -73.9872791},
#  {'name': 'Pier 76',
#   'review_count': 252,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.640118,
#   'longitude': -74.0759269},
#  {'name': 'Rocco Pizza',
#   'review_count': 204,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.69224,
#   'longitude': -73.945849},
#  {'name': 'Sotto Le Stelle',
#   'review_count': 344,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743656,
#   'longitude': -73.9201782},
#  {'name': "Cecconi's Dumbo",
#   'review_count': 1008,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.7033063330116,
#   'longitude': -73.9916549604523},
#  {'name': "Frank's Pizza",
#   'review_count': 137,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.617634,
#   'longitude': -73.931864},
#  {'name': 'Sauce Pizzeria',
#   'review_count': 79,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7204894,
#   'longitude': -73.98927},
#  {'name': 'Da Gennaro',
#   'review_count': 1238,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.71832,
#   'longitude': -73.99794},
#  {'name': 'Pizzatown',
#   'review_count': 90,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.680043,
#   'longitude': -73.977872},
#  {'name': 'Margherita Pizza',
#   'review_count': 351,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7045845329735,
#   'longitude': -73.7967360578922},
#  {'name': 'Proto’s Pizza',
#   'review_count': 109,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.725353,
#   'longitude': -73.989746},
#  {'name': 'Coletta',
#   'review_count': 151,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.74094,
#   'longitude': -73.98139},
#  {'name': 'Upside Pizza',
#   'review_count': 44,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75157,
#   'longitude': -73.98059},
#  {'name': 'Bread and Salt',
#   'review_count': 148,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7435428136099,
#   'longitude': -74.0447338297963},
#  {'name': "Famous Ben's Pizza",
#   'review_count': 388,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7249388,
#   'longitude': -74.002451},
#  {'name': "L'Artusi",
#   'review_count': 2218,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73372,
#   'longitude': -74.00513},
#  {'name': "Julie's Pizzeria & Restaurant",
#   'review_count': 61,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.704239,
#   'longitude': -73.9072084},
#  {'name': "Pop's Pizzas",
#   'review_count': 130,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.767086,
#   'longitude': -73.983033},
#  {'name': 'Carranza Pizza',
#   'review_count': 9,
#   'rating': 2.5,
#   'price': '$',
#   'latitude': 40.669342,
#   'longitude': -73.896667},
#  {'name': 'Malaparte',
#   'review_count': 394,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73687,
#   'longitude': -74.00812},
#  {'name': 'Triangolo Pizza',
#   'review_count': 134,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.73357,
#   'longitude': -73.955116},
#  {'name': "Sofia's Pizza",
#   'review_count': 260,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.67751,
#   'longitude': -73.82586},
#  {'name': 'Battle Hill Tavern',
#   'review_count': 48,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.66023,
#   'longitude': -73.99135},
#  {'name': 'Brooklyn Pizza Market',
#   'review_count': 114,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.68273,
#   'longitude': -73.99305},
#  {'name': 'Barosa',
#   'review_count': 412,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.726197,
#   'longitude': -73.869795},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 1685,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.74406421842744,
#   'longitude': -74.00655890429283},
#  {'name': "Ciccio's Pizza",
#   'review_count': 130,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.596872,
#   'longitude': -73.976309},
#  {'name': "Jiannetto's Pizza Truck",
#   'review_count': 36,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.70525,
#   'longitude': -74.00675},
#  {'name': "Tony's Brick Oven",
#   'review_count': 117,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.615321,
#   'longitude': -74.067035},
#  {'name': "Rosa's Pizza",
#   'review_count': 310,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.712192,
#   'longitude': -73.899997},
#  {'name': 'Carbone',
#   'review_count': 1528,
#   'rating': 4.0,
#   'price': '$$$$',
#   'latitude': 40.728,
#   'longitude': -74.0001497},
#  {'name': "Elio's",
#   'review_count': 296,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.7767632368091,
#   'longitude': -73.9526632086427},
#  {'name': "Totonno's",
#   'review_count': 832,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.578913225666966,
#   'longitude': -73.98383392883555},
#  {'name': 'Zero Otto Nove',
#   'review_count': 523,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7407551035259,
#   'longitude': -73.9914887388588},
#  {'name': 'Clinton Square Pizza',
#   'review_count': 88,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71395,
#   'longitude': -73.98724},
#  {'name': 'Union Pizza Works',
#   'review_count': 288,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7073067,
#   'longitude': -73.922154},
#  {'name': "J's Pizza",
#   'review_count': 144,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7398164,
#   'longitude': -73.9989453},
#  {'name': 'Casa Theodoro',
#   'review_count': 134,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75693,
#   'longitude': -73.906747},
#  {'name': 'Stage Door Pizzeria',
#   'review_count': 289,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.712121,
#   'longitude': -74.009704},
#  {'name': 'La Villa Pizzeria & Restaurant',
#   'review_count': 323,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.61692,
#   'longitude': -73.9098},
#  {'name': 'Fumo',
#   'review_count': 200,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.80285617298625,
#   'longitude': -73.968119},
#  {'name': 'Pizza Wagon',
#   'review_count': 299,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.62129,
#   'longitude': -74.02659},
#  {'name': '21 Greenpoint',
#   'review_count': 129,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.72978,
#   'longitude': -73.95992},
#  {'name': 'Double Zero',
#   'review_count': 605,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7261288,
#   'longitude': -73.9896645},
#  {'name': "Vito's Slices and Ices",
#   'review_count': 261,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7545,
#   'longitude': -73.99528},
#  {'name': 'Enzo Bruni Pizza Gourmet',
#   'review_count': 96,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.783433,
#   'longitude': -73.947932},
#  {'name': "Sam's Pizza",
#   'review_count': 155,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.87939,
#   'longitude': -73.90601},
#  {'name': 'Aurora',
#   'review_count': 786,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.715621,
#   'longitude': -73.964757},
#  {'name': 'Piatto',
#   'review_count': 234,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7435117,
#   'longitude': -73.9590968},
#  {'name': "Beebe's",
#   'review_count': 165,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.754827,
#   'longitude': -73.935918},
#  {'name': 'Neapolitan Express',
#   'review_count': 6,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.77991,
#   'longitude': -73.9818},
#  {'name': 'Koronet Pizza',
#   'review_count': 671,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.8044212,
#   'longitude': -73.96610978649716},
#  {'name': 'Champion Pizza',
#   'review_count': 93,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.73592407559118,
#   'longitude': -73.99391475241151},
#  {'name': 'Pizza Rollio',
#   'review_count': 180,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.764259,
#   'longitude': -73.974552},
#  {'name': "Freddy's Pizzeria",
#   'review_count': 105,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.788956,
#   'longitude': -73.814049},
#  {'name': 'Singas Famous Pizza',
#   'review_count': 120,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.75416828100335,
#   'longitude': -73.82289803347588},
#  {'name': "Screamer's Pizzeria",
#   'review_count': 429,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7235518,
#   'longitude': -73.95065},
#  {'name': 'Pazza Notte',
#   'review_count': 988,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76348,
#   'longitude': -73.978091},
#  {'name': 'Da Nonna Rosa',
#   'review_count': 425,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.67291,
#   'longitude': -73.97697},
#  {'name': 'Luigi Pizza',
#   'review_count': 54,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.69006,
#   'longitude': -73.84071},
#  {'name': "Rocco's Pizzeria",
#   'review_count': 109,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.62692170776024,
#   'longitude': -74.023899},
#  {'name': 'Liberty Pizzeria',
#   'review_count': 43,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.693225,
#   'longitude': -73.966018},
#  {'name': 'Broadway Pizzeria',
#   'review_count': 126,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6933151509676,
#   'longitude': -73.9290830120444},
#  {'name': "Johnny's Pizzeria",
#   'review_count': 404,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.917609,
#   'longitude': -73.839425},
#  {'name': 'Lillian Pizzeria',
#   'review_count': 283,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7169776965988,
#   'longitude': -73.8522986602726},
#  {'name': "Rosario's",
#   'review_count': 185,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.77479,
#   'longitude': -73.91186},
#  {'name': 'Little Italy Pizza',
#   'review_count': 597,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.756482,
#   'longitude': -73.981484},
#  {'name': "Sal's Pizzeria",
#   'review_count': 222,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7904646826957,
#   'longitude': -74.0151917526793},
#  {'name': 'Pizza Plus',
#   'review_count': 271,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.66585,
#   'longitude': -73.98211},
#  {'name': "Victor's Pizzeria & Italian Restaurant",
#   'review_count': 190,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.8898885,
#   'longitude': -74.0248396},
#  {'name': "Corleone's Pizzeria",
#   'review_count': 249,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.86922,
#   'longitude': -74.07036},
#  {'name': 'Spunto',
#   'review_count': 466,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7297584,
#   'longitude': -74.0046303},
#  {'name': 'The Uptown Garrison',
#   'review_count': 182,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8512380090093,
#   'longitude': -73.9392676530849},
#  {'name': 'Bklyn Pizza',
#   'review_count': 169,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.68903,
#   'longitude': -73.92408},
#  {'name': "Percy's Pizza",
#   'review_count': 251,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.729076,
#   'longitude': -74.001534},
#  {'name': 'Table 87 - Gowanus',
#   'review_count': 413,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.670664,
#   'longitude': -73.991371},
#  {'name': "Renato's Pizza Masters",
#   'review_count': 460,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7442813,
#   'longitude': -74.0503861},
#  {'name': 'Mama Mia 44 SW',
#   'review_count': 823,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.759761,
#   'longitude': -73.992065},
#  {'name': 'Eleven B',
#   'review_count': 235,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.72745,
#   'longitude': -73.97974},
#  {'name': 'Centro Pizza Bar & Italian Kitchen',
#   'review_count': 204,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.74494463643489,
#   'longitude': -73.95312334111576},
#  {'name': "Denino's Pizzeria & Tavern",
#   'review_count': 904,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6302266718896,
#   'longitude': -74.1402754933448},
#  {'name': "Ovest Pizzoteca by Luzzo's",
#   'review_count': 591,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7507476806641,
#   'longitude': -74.0030212402344},
#  {'name': "Santillo's Brick Oven Pizza",
#   'review_count': 498,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6489921895261,
#   'longitude': -74.21664536653269},
#  {'name': 'Hatchets & Hops - Brooklyn Axe Throwing',
#   'review_count': 21,
#   'rating': 5.0,
#   'price': '$$$',
#   'latitude': 40.7212414,
#   'longitude': -73.95767370825116},
#  {'name': 'The Swiss Slice',
#   'review_count': 32,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.655633751718426,
#   'longitude': -73.9503288},
#  {'name': 'Marabella Pizza',
#   'review_count': 144,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7402335928167,
#   'longitude': -73.9238661770474},
#  {'name': "Carmine's Italian Restaurant - Times Square",
#   'review_count': 4374,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75749848725768,
#   'longitude': -73.98665333142026},
#  {'name': '&pizza - NoMad',
#   'review_count': 520,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.74520457937066,
#   'longitude': -73.98823142051697},
#  {'name': "Paul's On Times Square",
#   'review_count': 343,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75522,
#   'longitude': -73.98539},
#  {'name': 'La Casa Bella',
#   'review_count': 304,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.590666,
#   'longitude': -73.991456},
#  {'name': "Arturo's",
#   'review_count': 768,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.73039,
#   'longitude': -74.27802},
#  {'name': 'Sweetbriar',
#   'review_count': 54,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.7422837,
#   'longitude': -73.9831629},
#  {'name': "Rosella's Pizzeria",
#   'review_count': 269,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.710117,
#   'longitude': -74.005661},
#  {'name': 'Motorino',
#   'review_count': 280,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7855672,
#   'longitude': -73.9730817},
#  {'name': "Gaby's Pizza",
#   'review_count': 509,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.720562,
#   'longitude': -73.7609024},
#  {'name': 'Pizza Secret',
#   'review_count': 233,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6808,
#   'longitude': -73.97764},
#  {'name': 'Slice Pizza',
#   'review_count': 59,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75202,
#   'longitude': -73.97376},
#  {'name': "Roberta's Pizza",
#   'review_count': 246,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.754393,
#   'longitude': -73.976103},
#  {'name': "Joe & Pat's Pizzeria",
#   'review_count': 467,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.61281,
#   'longitude': -74.12198},
#  {'name': 'Piccola Strada',
#   'review_count': 227,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72662,
#   'longitude': -73.99019},
#  {'name': 'La Nonna Ristorante & Bar',
#   'review_count': 404,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.718468787527,
#   'longitude': -73.9639185527139},
#  {'name': "Martiniello's III",
#   'review_count': 23,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.682871137684,
#   'longitude': -73.8510749861598},
#  {'name': 'Underground Pizza',
#   'review_count': 329,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70499,
#   'longitude': -74.00961},
#  {'name': 'Blaze Pizza',
#   'review_count': 213,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7403059,
#   'longitude': -73.78695268},
#  {'name': "Armando's Pizza",
#   'review_count': 72,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6835403,
#   'longitude': -73.9111862},
#  {'name': 'Rooftop Reds',
#   'review_count': 169,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7025733903159,
#   'longitude': -73.9698984748688},
#  {'name': "Pugsley's Pizza",
#   'review_count': 180,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.85881,
#   'longitude': -73.88475},
#  {'name': 'S & S Calabro Pizzeria',
#   'review_count': 55,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.769171,
#   'longitude': -73.931012},
#  {'name': 'Pasta by Hudson',
#   'review_count': 101,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7427486,
#   'longitude': -73.9969892},
#  {'name': 'Royal Pizzeria Restaurant',
#   'review_count': 9,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.655174,
#   'longitude': -73.887446},
#  {'name': 'Napoli Wood Fired Pizza & Bakery',
#   'review_count': 235,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.82846,
#   'longitude': -73.98608},
#  {'name': "Bedstuy Mike's Pizza",
#   'review_count': 31,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6958847045898,
#   'longitude': -73.9465713500977},
#  {'name': 'Sacco Pizza',
#   'review_count': 447,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7662658691406,
#   'longitude': -73.9872665405273},
#  {'name': "Sal's Pizzeria",
#   'review_count': 55,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69276,
#   'longitude': -73.85883},
#  {'name': "Tony's Pizza",
#   'review_count': 52,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.664924,
#   'longitude': -73.923379},
#  {'name': 'Original Pizza',
#   'review_count': 82,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.63465,
#   'longitude': -74.0233},
#  {'name': 'La Vera Pizzeria',
#   'review_count': 66,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74067,
#   'longitude': -73.98218},
#  {'name': "Sicily's Best Pizzeria",
#   'review_count': 88,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.70517,
#   'longitude': -73.915155},
#  {'name': "Ganni's Pizza",
#   'review_count': 115,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.69419,
#   'longitude': -73.957809},
#  {'name': 'Cozzi Pizza',
#   'review_count': 39,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.70377,
#   'longitude': -73.94749},
#  {'name': 'Pomodoro Ristorante & Pizzeria',
#   'review_count': 218,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.79655,
#   'longitude': -74.47547},
#  {'name': 'A-1 Pizza Shop',
#   'review_count': 36,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.715061,
#   'longitude': -73.982355},
#  {'name': 'Shelter Pizza',
#   'review_count': 336,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.71967,
#   'longitude': -73.9608499},
#  {'name': 'Canal Pizza',
#   'review_count': 26,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7153479526233,
#   'longitude': -73.9934167353488},
#  {'name': 'Tenth Street Pasta & Pizza',
#   'review_count': 268,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.74935270874642,
#   'longitude': -74.03135923715374},
#  {'name': 'Mariella Pizza',
#   'review_count': 120,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.76920133403351,
#   'longitude': -73.9629409622093},
#  {'name': "Luzzo's Neapolitan Pizza & Wine Bar",
#   'review_count': 139,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7492468,
#   'longitude': -73.9420071},
#  {'name': "Ray's Pizza",
#   'review_count': 401,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7604321973079,
#   'longitude': -73.9839891042824},
#  {'name': 'Famous Famiglia Pizzeria',
#   'review_count': 99,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.778337,
#   'longitude': -73.956623},
#  {'name': 'Gotham West Market',
#   'review_count': 565,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7624395,
#   'longitude': -73.9971462},
#  {'name': 'IL FORNO A LEGNA',
#   'review_count': 330,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6064118,
#   'longitude': -74.2743223},
#  {'name': 'Tino’s Artisan Pizza',
#   'review_count': 104,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71416668884163,
#   'longitude': -74.03979259017832},
#  {'name': 'Armonie',
#   'review_count': 123,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.799791923483,
#   'longitude': -73.942575354665},
#  {'name': 'Amore Pizzeria',
#   'review_count': 544,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7693570273757,
#   'longitude': -73.8341404931405},
#  {'name': "Dante's Pizza",
#   'review_count': 164,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7101589996558,
#   'longitude': -73.8482174277306},
#  {'name': 'Highline Pizzeria',
#   'review_count': 177,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.751049,
#   'longitude': -74.0020523},
#  {'name': 'Cozzi Pizza',
#   'review_count': 39,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.70377,
#   'longitude': -73.94749},
#  {'name': 'Pomodoro Ristorante & Pizzeria',
#   'review_count': 218,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.79655,
#   'longitude': -74.47547},
#  {'name': 'A-1 Pizza Shop',
#   'review_count': 36,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.715061,
#   'longitude': -73.982355},
#  {'name': 'Shelter Pizza',
#   'review_count': 336,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.71967,
#   'longitude': -73.9608499},
#  {'name': 'Canal Pizza',
#   'review_count': 26,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7153479526233,
#   'longitude': -73.9934167353488},
#  {'name': "Mike's Pizza",
#   'review_count': 83,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.655368,
#   'longitude': -73.9565781},
#  {'name': 'Tenth Street Pasta & Pizza',
#   'review_count': 268,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.74935270874642,
#   'longitude': -74.03135923715374},
#  {'name': 'Mariella Pizza',
#   'review_count': 120,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.76920133403351,
#   'longitude': -73.9629409622093},
#  {'name': "Luzzo's Neapolitan Pizza & Wine Bar",
#   'review_count': 139,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7492468,
#   'longitude': -73.9420071},
#  {'name': "Mike's Pizza",
#   'review_count': 118,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7385362974077,
#   'longitude': -73.9806645185456},
#  {'name': "Ray's Pizza",
#   'review_count': 401,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7604321973079,
#   'longitude': -73.9839891042824},
#  {'name': 'Famous Famiglia Pizzeria',
#   'review_count': 99,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.778337,
#   'longitude': -73.956623},
#  {'name': 'Gotham West Market',
#   'review_count': 565,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7624395,
#   'longitude': -73.9971462},
#  {'name': 'Grace Pizza',
#   'review_count': 116,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70214,
#   'longitude': -73.8807999},
#  {'name': 'IL FORNO A LEGNA',
#   'review_count': 330,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6064118,
#   'longitude': -74.2743223},
#  {'name': 'Tino’s Artisan Pizza',
#   'review_count': 104,
#   'rating': 4.5,
#   'price': '$$',
# ...
#  {'name': 'VIPizza',
#   'review_count': 343,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7612782716751,
#   'longitude': -73.7699277698994},
#  {'name': 'Benito One',
#   'review_count': 804,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7200188460948,
#   'longitude': -73.9969412164592},
#  {'name': 'Garden Pizza',
#   'review_count': 120,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.81648,
#   'longitude': -74.00288},
#  {'name': 'Brothers Pizza',
#   'review_count': 61,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.66341,
#   'longitude': -73.99468},
#  {'name': 'The River Café',
#   'review_count': 1260,
#   'rating': 4.0,
#   'price': '$$$$',
#   'latitude': 40.703866713051106,
#   'longitude': -73.99479360219303},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 280,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7517,
#   'longitude': -73.97432},
#  {'name': 'Ozone Pizza',
#   'review_count': 129,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6808917,
#   'longitude': -73.8426307},
#  {'name': 'Nova Pizza & Pasta',
#   'review_count': 155,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.84919,
#   'longitude': -73.97083},
#  {'name': "Sticky's Finger Joint",
#   'review_count': 462,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74505372839559,
#   'longitude': -73.9788811},
#  {'name': 'Carve',
#   'review_count': 450,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7602042287575,
#   'longitude': -73.9873568460327},
#  {'name': 'The Smith',
#   'review_count': 2019,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7716201269986,
#   'longitude': -73.9818377981476},
#  {'name': "D'Angelo's Pizzeria & Restaurant",
#   'review_count': 23,
#   'rating': 2.5,
#   'price': '$$',
#   'latitude': 40.83059,
#   'longitude': -73.85687},
#  {'name': "Ferdinando's Focacceria",
#   'review_count': 214,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68418116575449,
#   'longitude': -74.0018677711487},
#  {'name': 'Amici Ristorante',
#   'review_count': 172,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71981,
#   'longitude': -73.99722},
#  {'name': "Luigi's Pizzeria of Mineola",
#   'review_count': 205,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74450383,
#   'longitude': -73.65620367},
#  {'name': 'Bravo Pizza',
#   'review_count': 129,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.73863,
#   'longitude': -73.98727},
#  {'name': 'Mama Rosa Cucina Pizzeria',
#   'review_count': 78,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.648513,
#   'longitude': -74.138297},
#  {'name': "Gnoccheria By Luzzo's",
#   'review_count': 509,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.723315,
#   'longitude': -73.983139},
#  {'name': 'Frankies 457 Spuntino',
#   'review_count': 881,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.677328,
#   'longitude': -73.997972},
#  {'name': 'The Elgin',
#   'review_count': 231,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.758194,
#   'longitude': -73.980905},
#  {'name': 'Da Nico Ristorante',
#   'review_count': 982,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.71963,
#   'longitude': -73.99691},
#  {'name': 'Italian Village Pizzeria',
#   'review_count': 255,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.771447,
#   'longitude': -73.952994},
#  {'name': 'Osteria 57',
#   'review_count': 291,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73467,
#   'longitude': -73.99786},
#  {'name': 'Via Vai',
#   'review_count': 242,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7741502,
#   'longitude': -73.9123089},
#  {'name': 'Damascus Bakery',
#   'review_count': 5,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70322,
#   'longitude': -73.98308},
#  {'name': "Rose's Pizzeria",
#   'review_count': 159,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.863583,
#   'longitude': -74.104848},
#  {'name': 'Brother’s Pizzeria',
#   'review_count': 275,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7398,
#   'longitude': -73.788972},
#  {'name': 'De Palma Pizzeria & Ristorante',
#   'review_count': 81,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.763534,
#   'longitude': -74.033157},
#  {'name': 'Little Italy Pizza',
#   'review_count': 172,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7502738,
#   'longitude': -73.9909354},
#  {'name': 'Panello',
#   'review_count': 217,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.747536,
#   'longitude': -74.037906},
#  {'name': 'Roma Pizzeria',
#   'review_count': 51,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.80816,
#   'longitude': -74.00796},
#  {'name': 'La Bella Pizza',
#   'review_count': 47,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6049099,
#   'longitude': -73.9977399},
#  {'name': 'La Scala Restaurant & Pizzeria',
#   'review_count': 286,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.815935283241,
#   'longitude': -73.291973754201},
#  {'name': "Manetta's Ristorante",
#   'review_count': 442,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7427,
#   'longitude': -73.95184},
#  {'name': 'Prime Pizza Kitchen',
#   'review_count': 67,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.5853249350922,
#   'longitude': -74.0926520634632},
#  {'name': "Romeo's Pizzeria",
#   'review_count': 97,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.681713,
#   'longitude': -73.83699},
#  {'name': 'Johnny Pepperoni',
#   'review_count': 394,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75011,
#   'longitude': -74.02969},
#  {'name': "Lenny's Pizza",
#   'review_count': 145,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74145,
#   'longitude': -73.92022},
#  {'name': 'Mulberry St. Pizza',
#   'review_count': 125,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7791410258621,
#   'longitude': -73.5295731686245},
#  {'name': '1653 Pizza Company',
#   'review_count': 76,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8716723,
#   'longitude': -73.4304367},
#  {'name': "Joe's Pizza",
#   'review_count': 29,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.83766,
#   'longitude': -73.86479},
#  {'name': 'Famous Famiglia Pizzeria ',
#   'review_count': 94,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.76569739383,
#   'longitude': -73.9573263022275},
#  {'name': 'Prima Pizza',
#   'review_count': 58,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6937218,
#   'longitude': -73.8527069},
#  {'name': 'Astoria Family Pizza',
#   'review_count': 64,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7808503,
#   'longitude': -73.9169041},
#  {'name': 'Sauce Pizzeria',
#   'review_count': 257,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73033,
#   'longitude': -73.98403},
#  {'name': 'Parm',
#   'review_count': 855,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.72303,
#   'longitude': -73.99567},
#  {'name': "Lee's Tavern",
#   'review_count': 616,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.588756,
#   'longitude': -74.095153},
#  {'name': "Patrizia's Of Maspeth",
#   'review_count': 256,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.726783,
#   'longitude': -73.894276},
#  {'name': 'Sorrento Pizzeria',
#   'review_count': 98,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.85447,
#   'longitude': -73.85438},
#  {'name': 'Yankee J-Z Pizza',
#   'review_count': 64,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.8292327076197,
#   'longitude': -73.8757006824017},
#  {'name': 'Mia Pizza',
#   'review_count': 130,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.77907,
#   'longitude': -73.91439},
#  {'name': "Brother's Pizzeria",
#   'review_count': 263,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.625598,
#   'longitude': -74.143835},
#  {'name': 'Porto Bello',
#   'review_count': 226,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.770352,
#   'longitude': -73.904303},
#  {'name': 'Lupa',
#   'review_count': 1708,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7276,
#   'longitude': -74.000045},
#  {'name': "The Original Sal's Pizza",
#   'review_count': 41,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.700424,
#   'longitude': -73.896354},
#  {'name': 'Sullivan Street Bakery',
#   'review_count': 544,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7473222,
#   'longitude': -74.0004691},
#  {'name': "Strawberry's Pub & Pizza",
#   'review_count': 380,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.5446448928292,
#   'longitude': -74.276500967984},
#  {'name': 'Low Fidelity',
#   'review_count': 173,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.73977,
#   'longitude': -74.04679},
#  {'name': 'Kiss My Slice',
#   'review_count': 262,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75576,
#   'longitude': -73.99052},
#  {'name': 'Beverley Pizza & Cafe',
#   'review_count': 129,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.64255,
#   'longitude': -73.97832},
#  {'name': 'Four Corners Pizza',
#   'review_count': 66,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.8960026,
#   'longitude': -73.8054674},
#  {'name': 'Gotham Pizza',
#   'review_count': 135,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.777568,
#   'longitude': -73.949218},
#  {'name': 'Ulivo',
#   'review_count': 365,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7447371960713,
#   'longitude': -73.9880339428782},
#  {'name': "Helen's Pizza",
#   'review_count': 192,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7212072,
#   'longitude': -74.0456498},
#  {'name': "Charlie's Pizzeria",
#   'review_count': 26,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6454519,
#   'longitude': -74.0101539},
#  {'name': 'Via Roma Pizza Bar',
#   'review_count': 60,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6780373,
#   'longitude': -73.9977648},
#  {'name': "Grimaldi's",
#   'review_count': 392,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.75453,
#   'longitude': -73.73854},
#  {'name': 'S. Egidio',
#   'review_count': 534,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.980227,
#   'longitude': -74.120093},
#  {'name': 'Anthony Francos Pizza - Fort Lee',
#   'review_count': 100,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.85118424054,
#   'longitude': -73.9690647558935},
#  {'name': 'Centre Pizzeria and Restaurant',
#   'review_count': 210,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.76447,
#   'longitude': -73.726049},
#  {'name': 'Enoteca Maria',
#   'review_count': 421,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.642,
#   'longitude': -74.07729},
#  {'name': "Joe's Pizza",
#   'review_count': 29,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.83766,
#   'longitude': -73.86479},
#  {'name': 'Famous Famiglia Pizzeria ',
#   'review_count': 94,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.76569739383,
#   'longitude': -73.9573263022275},
#  {'name': 'Astoria Family Pizza',
#   'review_count': 64,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7808503,
#   'longitude': -73.9169041},
#  {'name': 'Sauce Pizzeria',
#   'review_count': 257,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73033,
#   'longitude': -73.98403},
#  {'name': 'Parm',
#   'review_count': 855,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.72303,
#   'longitude': -73.99567},
#  {'name': "Lee's Tavern",
#   'review_count': 616,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.588756,
#   'longitude': -74.095153},
#  {'name': "Patrizia's Of Maspeth",
#   'review_count': 256,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.726783,
#   'longitude': -73.894276},
#  {'name': 'Sorrento Pizzeria',
#   'review_count': 98,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.85447,
#   'longitude': -73.85438},
#  {'name': 'Supper',
#   'review_count': 1455,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72290786539601,
#   'longitude': -73.98520720537888},
#  {'name': 'Yankee J-Z Pizza',
#   'review_count': 64,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.8292327076197,
#   'longitude': -73.8757006824017},
#  {'name': 'Mia Pizza',
#   'review_count': 130,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.77907,
#   'longitude': -73.91439},
#  {'name': "Brother's Pizzeria",
#   'review_count': 263,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.625598,
#   'longitude': -74.143835},
#  {'name': 'Porto Bello',
#   'review_count': 226,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.770352,
#   'longitude': -73.904303},
#  {'name': 'Franklin Pizza',
#   'review_count': 60,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.729684,
#   'longitude': -73.957827},
#  {'name': 'Lupa',
#   'review_count': 1708,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7276,
#   'longitude': -74.000045},
#  {'name': "The Original Sal's Pizza",
#   'review_count': 41,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.700424,
#   'longitude': -73.896354},
#  {'name': 'Sullivan Street Bakery',
#   'review_count': 544,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7473222,
#   'longitude': -74.0004691},
#  {'name': "Strawberry's Pub & Pizza",
#   'review_count': 380,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.5446448928292,
#   'longitude': -74.276500967984},
#  {'name': 'Low Fidelity',
#   'review_count': 173,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.73977,
#   'longitude': -74.04679},
#  {'name': 'Kiss My Slice',
#   'review_count': 262,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75576,
#   'longitude': -73.99052},
#  {'name': 'Beverley Pizza & Cafe',
#   'review_count': 129,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.64255,
#   'longitude': -73.97832},
#  {'name': 'Four Corners Pizza',
#   'review_count': 66,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.8960026,
#   'longitude': -73.8054674},
#  {'name': 'Gotham Pizza',
#   'review_count': 135,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.777568,
#   'longitude': -73.949218},
#  {'name': 'Ulivo',
#   'review_count': 365,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7447371960713,
#   'longitude': -73.9880339428782},
#  {'name': 'City Island Delicatessan',
#   'review_count': 4,
#   'rating': 5.0,
#   'price': '$',
#   'latitude': 40.85258,
#   'longitude': -73.789129},
#  {'name': "Helen's Pizza",
#   'review_count': 192,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7212072,
#   'longitude': -74.0456498},
#  {'name': 'Industry Kitchen',
#   'review_count': 880,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7049434740873,
#   'longitude': -74.0048825740814},
#  {'name': "Charlie's Pizzeria",
#   'review_count': 26,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6454519,
#   'longitude': -74.0101539},
#  {'name': 'Via Roma Pizza Bar',
#   'review_count': 60,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6780373,
#   'longitude': -73.9977648},
#  {'name': 'S. Egidio',
#   'review_count': 534,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.980227,
#   'longitude': -74.120093},
#  {'name': 'Centre Pizzeria and Restaurant',
#   'review_count': 210,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.76447,
#   'longitude': -73.726049},
#  {'name': "Marie's 2",
#   'review_count': 85,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.64224,
#   'longitude': -74.07674},
#  {'name': 'Taste of Tuscany',
#   'review_count': 99,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8568353549895,
#   'longitude': -74.0434074881405},
#  {'name': 'Famous Original Ray’s Pizza',
#   'review_count': 426,
#   'rating': 2.5,
#   'price': '$',
#   'latitude': 40.76038,
#   'longitude': -73.984},
#  {'name': 'Longo Bros',
#   'review_count': 66,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.754825,
#   'longitude': -73.994862},
#  {'name': 'Fiamma Wood Fired Pizza',
#   'review_count': 343,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6511098,
#   'longitude': -74.3478367},
#  {'name': 'Great Burrito',
#   'review_count': 266,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7428322,
#   'longitude': -73.9930115},
#  {'name': 'Basta Pasta',
#   'review_count': 1509,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73881,
#   'longitude': -73.99407},
#  {'name': 'The Pizza Place',
#   'review_count': 109,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.640716,
#   'longitude': -73.699516},
#  {'name': 'Scarpetta',
#   'review_count': 2200,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.744509,
#   'longitude': -73.9856},
#  {'name': 'A Pasta Bar',
#   'review_count': 460,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.72229,
#   'longitude': -74.00403},
#  {'name': "Fedoroff's Roast Pork",
#   'review_count': 350,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7189526,
#   'longitude': -73.9555245}]

# %% [markdown]
# This code may take up to a few minutes to run.
#
# If you get an error trying to get the response body in JSON format, try adding `time.sleep(1)` right after the `requests.get` line, so your code will sleep for 1 second between each API call.

# %% [markdown]
# ## 3. Perform Exploratory Analysis
#
# Take the businesses from the previous question and do an initial exploratory analysis. We have provided some plots for you to interpret:

# %%
# Run this cell without changes
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(16, 5))

# Plot distribution of number of reviews
all_review_counts = [x["review_count"] for x in full_dataset]
ax1.hist(all_review_counts)
ax1.set_title("Review Count Distribution")
ax1.set_xlabel("Number of Reviews")
ax1.set_ylabel("Number of Businesses")

# Plot rating distribution
all_ratings = [x["rating"] for x in full_dataset]
rating_counter = Counter(all_ratings)
rating_keys = sorted(rating_counter.keys())
ax2.bar(rating_keys, [rating_counter[key] for key in rating_keys])
ax2.set_title("Rating Distribution")
ax2.set_xlabel("Rating")
ax2.set_ylabel("Number of Businesses")

# Plot price distribution
all_prices = [x["price"].replace("$", r"\$") for x in full_dataset]
price_counter = Counter(all_prices)
price_keys = sorted(price_counter.keys())
ax3.bar(price_keys, [price_counter[key] for key in price_keys])
ax3.set_title("Price Distribution")
ax3.set_xlabel("Price Category")
ax3.set_ylabel("Number of Businesses");

"""hist and counter are doing same thing here***Mine"""

# %% [markdown]
# Describe the distributions displayed above and interpret them in the context of your query. (Your answer may differ from the solution branch depending on your query.)

# %%
# Replace None with appropriate text
"""
First we can see most businesses have reviews count below 500. There are few businesses 
that have more than 6000 reviews. I'd like to see the rating of those businesses.

Second, ratings are mostly around 4-4.5.

Third, prices are mostly around 2 $$ or below. 
"""

# %% [markdown]
# In the cell below, we also plot the rating distributions by price. In this setup, a price of one dollar sign is "lower price" and everything else is "higher price".

# %%
# Run this cell without changes

higher_price = []
lower_price = []
for row in full_dataset:
    if row["price"] == "$":
        lower_price.append(row["rating"])
    else:
        higher_price.append(row["rating"])
        
fig, ax = plt.subplots()

ax.hist([higher_price, lower_price], label=["higher price", "lower price"], density=True)

ax.legend();

# %% [markdown]
# Is a higher price associated with a higher rating? (No need for any additional math/statistics, just interpret what you see in the plot.)

# %%
# Replace None with appropriate text
"""
For rating equal to 3.5 or below, businesses with lower price are more than those with 
higher price. It is on the contrary when comes to rating equal to 4 or higher. So we can
say in the sample we draws, higher price means higher rating.
"""

# %% [markdown]
# Finally, let's look at ratings vs. review counts:

# %%
# Run this cell without changes
fig, ax = plt.subplots(figsize=(16,5))

ax.scatter(all_review_counts, all_ratings, alpha=0.2)
ax.set_xlabel("Number of Reviews")
ax.set_ylabel("Rating")
# "zoom in" to a subset of review counts
ax.set_xlim(left=0, right=1000);

# %% [markdown]
# Is a higher number of reviews associated with a higher rating?

# %%
# Replace None with appropriate text
"""
No, even though higher number of reviews shows more higher ratings when rating are below 4,
we don't see it when rating are above 4. 
"""

# %% [markdown]
# ## 4. Create a Folium Map
#
# Make a map using Folium of the businesses you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.
#
# You can center the map around the latitude and longitude of the first item in `full_dataset`.

# %%
full_dataset
# Out:
# [{'name': "Juliana's",
#   'review_count': 2601,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70274718768062,
#   'longitude': -73.99343490196397},
#  {'name': "L'industrie Pizzeria",
#   'review_count': 859,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.71162,
#   'longitude': -73.95783},
#  {'name': 'Rubirosa',
#   'review_count': 2889,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.722766,
#   'longitude': -73.996233},
#  {'name': "Lombardi's Pizza",
#   'review_count': 6520,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7215934960083,
#   'longitude': -73.9955956044561},
#  {'name': "Joe's Pizza",
#   'review_count': 2957,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73060076,
#   'longitude': -74.00215997},
#  {'name': "Joe's Pizza",
#   'review_count': 1754,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7547,
#   'longitude': -73.98696},
#  {'name': "Joe's Pizza",
#   'review_count': 1037,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73331,
#   'longitude': -73.98763},
#  {'name': 'Lucali',
#   'review_count': 1926,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.681840746711224,
#   'longitude': -74.0003327},
#  {'name': "Scarr's Pizza",
#   'review_count': 691,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71534,
#   'longitude': -73.9914},
#  {'name': "John's of Bleecker Street",
#   'review_count': 2488,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73158,
#   'longitude': -74.00332},
#  {'name': "Paulie Gee's",
#   'review_count': 1330,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.729546,
#   'longitude': -73.958568},
#  {'name': "Grimaldi's Pizzeria",
#   'review_count': 4907,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7026459,
#   'longitude': -73.9932413},
#  {'name': 'Piz-zetta',
#   'review_count': 331,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69116658201196,
#   'longitude': -73.99065911521895},
#  {'name': "Joe's Pizza",
#   'review_count': 433,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7168952,
#   'longitude': -73.95892996733771},
#  {'name': 'Nolita Pizza',
#   'review_count': 182,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7208883,
#   'longitude': -73.9962404},
#  {'name': "Lil Frankie's",
#   'review_count': 1414,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.723625,
#   'longitude': -73.988555},
#  {'name': 'Front Street Pizza',
#   'review_count': 447,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70244,
#   'longitude': -73.98943},
#  {'name': 'Barano',
#   'review_count': 307,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.710372,
#   'longitude': -73.96794},
#  {'name': "Joe's Pizza",
#   'review_count': 422,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7101297729083,
#   'longitude': -74.0077206864953},
#  {'name': 'Sottocasa Pizzeria',
#   'review_count': 701,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.688285,
#   'longitude': -73.989006},
#  {'name': "Roberta's",
#   'review_count': 3223,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70493,
#   'longitude': -73.93399},
#  {'name': 'L & B Spumoni Gardens',
#   'review_count': 4495,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.594715,
#   'longitude': -73.981316},
#  {'name': 'Village Square Pizza',
#   'review_count': 259,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72748,
#   'longitude': -73.98268},
#  {'name': 'Marinara Pizza',
#   'review_count': 320,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7826,
#   'longitude': -73.95351},
#  {'name': "Ace's Pizza",
#   'review_count': 132,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71505,
#   'longitude': -73.958365},
#  {'name': 'Il Porto',
#   'review_count': 380,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6974427,
#   'longitude': -73.9675197},
#  {'name': 'Song E Napule',
#   'review_count': 665,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72813,
#   'longitude': -74.00188},
#  {'name': "Dellarocco's Brick Oven Pizza",
#   'review_count': 341,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6950309,
#   'longitude': -73.9961252},
#  {'name': "Adrienne's Pizzabar",
#   'review_count': 1817,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7043362,
#   'longitude': -74.0101733},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 670,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.76458,
#   'longitude': -73.98247},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 608,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6818695,
#   'longitude': -73.976181},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 4163,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7321124557704,
#   'longitude': -73.9839056828882},
#  {'name': "MAMA'S TOO!",
#   'review_count': 604,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.80084,
#   'longitude': -73.96766},
#  {'name': 'Cuts & Slices',
#   'review_count': 256,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6854737,
#   'longitude': -73.9203186},
#  {'name': 'Ops',
#   'review_count': 183,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70276,
#   'longitude': -73.9171},
#  {'name': 'Champion Pizza',
#   'review_count': 414,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7215270996094,
#   'longitude': -73.9970855712891},
#  {'name': "Paulie Gee's Slice Shop",
#   'review_count': 308,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72836,
#   'longitude': -73.9572},
#  {'name': "Patrizia's - Williamsburg",
#   'review_count': 783,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7109154314181,
#   'longitude': -73.9673637711639},
#  {'name': 'NY Pizza Suprema',
#   'review_count': 2400,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7502059936523,
#   'longitude': -73.9953231811523},
#  {'name': "Patrizia's - Williamsburg",
#   'review_count': 783,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7109154314181,
#   'longitude': -73.9673637711639},
#  {'name': "Brooklyn's Homeslice Pizzeria",
#   'review_count': 186,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.680702,
#   'longitude': -73.967455},
#  {'name': "Luigi's Pizzeria",
#   'review_count': 280,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6897,
#   'longitude': -73.965369},
#  {'name': "Tony's Pizzeria of Nassau Ave",
#   'review_count': 63,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.725290886426,
#   'longitude': -73.946226015687},
#  {'name': 'Da Andrea',
#   'review_count': 1783,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.736218,
#   'longitude': -73.99597},
#  {'name': 'My Pie Pizzeria Romana',
#   'review_count': 887,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7608512,
#   'longitude': -73.9694809},
#  {'name': 'Levante',
#   'review_count': 323,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74764,
#   'longitude': -73.94173},
#  {'name': 'Il Mattone',
#   'review_count': 105,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.720799,
#   'longitude': -74.0091255},
#  {'name': 'Goodfellas Pizzeria of LIC',
#   'review_count': 78,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75334,
#   'longitude': -73.93716},
#  {'name': "Louie's Pizza",
#   'review_count': 526,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.74600424769782,
#   'longitude': -73.88356062541311},
#  {'name': "Tony's Pizzeria & Restaurant",
#   'review_count': 354,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.699286,
#   'longitude': -73.918724},
#  {'name': 'Krispy Pizza ',
#   'review_count': 324,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.62236,
#   'longitude': -74.0055},
#  {'name': 'Siena Pizza & Cannoli',
#   'review_count': 90,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.708152,
#   'longitude': -74.013864},
#  {'name': 'Di Fara Pizza',
#   'review_count': 3940,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.625093,
#   'longitude': -73.961531},
#  {'name': 'Ribalta Pizza',
#   'review_count': 733,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7334346,
#   'longitude': -73.9916923},
#  {'name': 'Fornino',
#   'review_count': 291,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.692930215177675,
#   'longitude': -74.00165153160219},
#  {'name': 'Sofia Pizza Shoppe',
#   'review_count': 240,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75674,
#   'longitude': -73.96431},
#  {'name': 'Adoro Lei',
#   'review_count': 356,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.725612,
#   'longitude': -74.007916},
#  {'name': 'Lucia Pizza',
#   'review_count': 629,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.76032,
#   'longitude': -73.82813},
#  {'name': 'Stone Bridge Pizza & Salad',
#   'review_count': 318,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.75225,
#   'longitude': -73.98061},
#  {'name': "Louie & Ernie's Pizza",
#   'review_count': 371,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.838288,
#   'longitude': -73.828563},
#  {'name': "Joe & Pat's Pizzeria",
#   'review_count': 275,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72892,
#   'longitude': -73.98411},
#  {'name': 'Wheated',
#   'review_count': 371,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6465968960541,
#   'longitude': -73.9704950265688},
#  {'name': 'Barboncino Pizza & Bar',
#   'review_count': 1104,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.67206,
#   'longitude': -73.95717},
#  {'name': 'Lo Duca Pizza',
#   'review_count': 148,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6349400235262,
#   'longitude': -73.9625812061059},
#  {'name': 'Time Out Market New York',
#   'review_count': 444,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70342863348067,
#   'longitude': -73.99214637055226},
#  {'name': 'B Side Pizza & Wine Bar',
#   'review_count': 1267,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.76388,
#   'longitude': -73.98821},
#  {'name': 'Saraghina Pizzeria',
#   'review_count': 992,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6837407,
#   'longitude': -73.9353473},
#  {'name': 'Motorino Pizzeria Napoletana',
#   'review_count': 265,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7104799,
#   'longitude': -73.96351},
#  {'name': 'Pizza Barn',
#   'review_count': 496,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.92033366683442,
#   'longitude': -73.86751644723435},
#  {'name': 'Sottocasa Pizzeria - Harlem',
#   'review_count': 330,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.8055499,
#   'longitude': -73.94746},
#  {'name': "Angelo's Coal Oven Pizzeria",
#   'review_count': 1112,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76492,
#   'longitude': -73.97794},
#  {'name': 'Razza',
#   'review_count': 1150,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7177776,
#   'longitude': -74.0442612},
#  {'name': 'J & V Pizzeria',
#   'review_count': 271,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6199507795829,
#   'longitude': -73.9896828},
#  {'name': 'La Villa',
#   'review_count': 583,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6743319055498,
#   'longitude': -73.9816949398812},
#  {'name': "Giuseppina's",
#   'review_count': 347,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6603430973463,
#   'longitude': -73.9907741546631},
#  {'name': "Mike's Pizza",
#   'review_count': 147,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75214,
#   'longitude': -73.934339},
#  {'name': 'Luna Pizza',
#   'review_count': 99,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.713245675315,
#   'longitude': -73.998651104496},
#  {'name': "Fresco's Pizzeria",
#   'review_count': 242,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.8551130123675,
#   'longitude': -73.9372547647758},
#  {'name': 'Leuca',
#   'review_count': 411,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.722121,
#   'longitude': -73.956678},
#  {'name': "Joe & John's Pizzeria",
#   'review_count': 174,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7003933525757,
#   'longitude': -73.8993881901177},
#  {'name': 'Lions & Tigers & Squares Detroit Pizza',
#   'review_count': 532,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.74506,
#   'longitude': -73.99834},
#  {'name': 'Milkflower',
#   'review_count': 745,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7628961,
#   'longitude': -73.9207081},
#  {'name': 'Dough Vale',
#   'review_count': 101,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70933,
#   'longitude': -73.95407},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 924,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.797157,
#   'longitude': -73.93488},
#  {'name': "Arturo's",
#   'review_count': 758,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7273563342024,
#   'longitude': -74.0004944801331},
#  {'name': '&pizza - Astor Place',
#   'review_count': 211,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72981093692917,
#   'longitude': -73.9926904},
#  {'name': 'Loring Place',
#   'review_count': 524,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73293764919451,
#   'longitude': -73.99758608256435},
#  {'name': "Emmett's",
#   'review_count': 590,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.727303,
#   'longitude': -74.00243},
#  {'name': 'Fascati Pizza',
#   'review_count': 263,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6985,
#   'longitude': -73.99273},
#  {'name': 'SIMÒ PIZZA',
#   'review_count': 235,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7392597584612,
#   'longitude': -74.0088130692187},
#  {'name': "Carmine's Pizzeria",
#   'review_count': 516,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.714987,
#   'longitude': -73.94414},
#  {'name': 'La Lanterna Di Vittorio',
#   'review_count': 1620,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73069,
#   'longitude': -74.00015},
#  {'name': "Nick's Pizza",
#   'review_count': 581,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.78272735790179,
#   'longitude': -73.9478073},
#  {'name': 'Jentana Pizza Restaurant',
#   'review_count': 74,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6375122070312,
#   'longitude': -73.9994735717773},
#  {'name': 'Don Antonio',
#   'review_count': 1623,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.762711,
#   'longitude': -73.986708},
#  {'name': 'Roma Pizza',
#   'review_count': 378,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.77843,
#   'longitude': -73.94863},
#  {'name': 'Emmy Squared Pizza - East Village ',
#   'review_count': 349,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72598,
#   'longitude': -73.98672},
#  {'name': "Luna's Pizzeria & Restaurant",
#   'review_count': 9,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7603635173753,
#   'longitude': -74.0371671497532},
#  {'name': 'Sauce',
#   'review_count': 916,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7204716,
#   'longitude': -73.9893263},
#  {'name': 'Don Angie',
#   'review_count': 629,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73778,
#   'longitude': -74.00197},
#  {'name': 'Inatteso Pizzabar',
#   'review_count': 344,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7056571,
#   'longitude': -74.0172056},
#  {'name': 'Follia',
#   'review_count': 272,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7349243164062,
#   'longitude': -73.9855880737305},
#  {'name': 'Margherita NYC',
#   'review_count': 317,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7189865112305,
#   'longitude': -73.9969329833984},
#  {'name': "Luzzo's BK",
#   'review_count': 213,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.690706,
#   'longitude': -73.9952269},
#  {'name': 'Circa Brewing',
#   'review_count': 403,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.69165,
#   'longitude': -73.98603},
#  {'name': 'Leo',
#   'review_count': 79,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7125608,
#   'longitude': -73.9567886},
#  {'name': "Rosa's Pizza",
#   'review_count': 440,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72697,
#   'longitude': -73.89564},
#  {'name': 'Santa Panza',
#   'review_count': 219,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6947,
#   'longitude': -73.93068},
#  {'name': 'Pizza Palace',
#   'review_count': 142,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.8629818681867,
#   'longitude': -73.9256393909454},
#  {'name': 'GRUPPO NYCThinCrust Pizza',
#   'review_count': 272,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72474,
#   'longitude': -73.98161},
#  {'name': 'Ci Siamo',
#   'review_count': 225,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.75240549384363,
#   'longitude': -73.9982864846782},
#  {'name': 'Circa Brewing',
#   'review_count': 403,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.69165,
#   'longitude': -73.98603},
#  {'name': 'Leo',
#   'review_count': 79,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7125608,
#   'longitude': -73.9567886},
#  {'name': "Rosa's Pizza",
#   'review_count': 440,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72697,
#   'longitude': -73.89564},
#  {'name': 'Santa Panza',
#   'review_count': 219,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6947,
#   'longitude': -73.93068},
#  {'name': 'Pizza Palace',
#   'review_count': 142,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.8629818681867,
#   'longitude': -73.9256393909454},
#  {'name': 'Motorino',
#   'review_count': 1112,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73039,
#   'longitude': -73.98381},
#  {'name': 'Ci Siamo',
#   'review_count': 225,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.75240549384363,
#   'longitude': -73.9982864846782},
#  {'name': '&pizza - Wall St',
#   'review_count': 140,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7057647,
#   'longitude': -74.0085474},
#  {'name': "Lombardo's of Bay Ridge",
#   'review_count': 189,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.634741,
#   'longitude': -74.0284259},
#  {'name': 'Piacere',
#   'review_count': 710,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7196979,
#   'longitude': -73.9951175},
#  {'name': 'Famous Calabria',
#   'review_count': 97,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.711942,
#   'longitude': -73.999349},
#  {'name': 'Pizzette',
#   'review_count': 67,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70858,
#   'longitude': -73.94357},
#  {'name': 'Marta',
#   'review_count': 988,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7445882,
#   'longitude': -73.9847936},
#  {'name': 'New Park Pizza',
#   'review_count': 1010,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6627403949909,
#   'longitude': -73.8403776268684},
#  {'name': 'Trapizzino',
#   'review_count': 286,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72043,
#   'longitude': -73.98894},
#  {'name': 'Fumo Pizza-Bar-Pasta',
#   'review_count': 551,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.821427,
#   'longitude': -73.950638},
#  {'name': "Roey's",
#   'review_count': 168,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73596,
#   'longitude': -74.00093},
#  {'name': 'Tavola',
#   'review_count': 1218,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.755403,
#   'longitude': -73.994516},
#  {'name': "Natoli's",
#   'review_count': 325,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.79508,
#   'longitude': -74.06316},
#  {'name': "Freddie & Pepper's",
#   'review_count': 517,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.779999,
#   'longitude': -73.980301},
#  {'name': 'Paesano of Mulberry Street',
#   'review_count': 1317,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.718554,
#   'longitude': -73.997447},
#  {'name': 'Artistic Pizza',
#   'review_count': 106,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.73068,
#   'longitude': -74.00042},
#  {'name': 'Campania Coal Fired Pizza',
#   'review_count': 665,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6136093139648,
#   'longitude': -74.033332824707},
#  {'name': 'Eataly NYC Flatiron',
#   'review_count': 6021,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74200824886595,
#   'longitude': -73.98993910744127},
#  {'name': "Sam's",
#   'review_count': 236,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.685920715332,
#   'longitude': -73.9945220947266},
#  {'name': 'Sotto 13',
#   'review_count': 1029,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7372,
#   'longitude': -73.99919},
#  {'name': 'BRADO NYCThinCrust Pizza',
#   'review_count': 160,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6905570310882,
#   'longitude': -73.99494681265617},
#  {'name': "Nick's Pizza - Forest Hills",
#   'review_count': 959,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.71797254115706,
#   'longitude': -73.84048067055303},
#  {'name': 'Speedy Romeo',
#   'review_count': 660,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6875154792236,
#   'longitude': -73.959874469611},
#  {'name': 'Rosemary’s',
#   'review_count': 194,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.735097,
#   'longitude': -73.979074},
#  {'name': "Romeo's Pizza",
#   'review_count': 160,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7291074,
#   'longitude': -73.7808497},
#  {'name': 'Williamsburg Pizza',
#   'review_count': 271,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71822,
#   'longitude': -73.99123},
#  {'name': 'POSTO NYCThinCrust Pizza',
#   'review_count': 659,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73483,
#   'longitude': -73.98282},
#  {'name': 'POSTO NYCThinCrust Pizza',
#   'review_count': 659,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73483,
#   'longitude': -73.98282},
#  {'name': "G&J's Pizzeria",
#   'review_count': 70,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7903349463747,
#   'longitude': -73.946079551947},
#  {'name': 'Bono Trattoria',
#   'review_count': 354,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.8301996389829,
#   'longitude': -73.9473449424522},
#  {'name': 'K Pizza',
#   'review_count': 68,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.842018,
#   'longitude': -74.000809},
#  {'name': 'Numero 28 Ristorante Pizzeria Bar',
#   'review_count': 573,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73041,
#   'longitude': -73.98595},
#  {'name': 'DaVinci Pizzeria',
#   'review_count': 154,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.618881,
#   'longitude': -73.990798},
#  {'name': 'Xtra Cheese Pizza',
#   'review_count': 131,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7651362,
#   'longitude': -73.8182876},
#  {'name': 'Two Boots Pizza - West Village',
#   'review_count': 55,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.73314309005766,
#   'longitude': -74.0027964258894},
#  {'name': 'Emily',
#   'review_count': 899,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68351,
#   'longitude': -73.96643},
#  {'name': 'Peperino NYC Pizza',
#   'review_count': 99,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.77275912931571,
#   'longitude': -73.99077586611165},
#  {'name': "Joe's Pizza",
#   'review_count': 8,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.85392,
#   'longitude': -73.88413},
#  {'name': 'Osteria Brooklyn',
#   'review_count': 164,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.693154,
#   'longitude': -73.967177},
#  {'name': 'VEZZO NYCThinCrust Pizza',
#   'review_count': 1379,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.744435447210506,
#   'longitude': -73.9814189},
#  {'name': 'Salvatores of Soho',
#   'review_count': 334,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8875232,
#   'longitude': -73.90704},
#  {'name': 'Milano Pizzeria',
#   'review_count': 36,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7968348033007,
#   'longitude': -73.93813295643352},
#  {'name': 'Love & Dough',
#   'review_count': 245,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.702950557308085,
#   'longitude': -73.98748593042708},
#  {'name': "John's of Times Square",
#   'review_count': 2361,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75823,
#   'longitude': -73.98836},
#  {'name': "Lazzara's Pizza",
#   'review_count': 336,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.754057,
#   'longitude': -73.989497},
#  {'name': 'Parm',
#   'review_count': 409,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.714473491420726,
#   'longitude': -74.01609333303082},
#  {'name': 'Oath Pizza - New York',
#   'review_count': 259,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7664835,
#   'longitude': -73.9633564},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 294,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.70638449968762,
#   'longitude': -73.92288771165168},
#  {'name': "Rizzo's Fine Pizza",
#   'review_count': 650,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.76337,
#   'longitude': -73.915124},
#  {'name': 'Village Pizza',
#   'review_count': 155,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73927,
#   'longitude': -74.00321},
#  {'name': "Vic's",
#   'review_count': 560,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72693,
#   'longitude': -73.99319},
#  {'name': 'Emily - West Village',
#   'review_count': 920,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.729375015649076,
#   'longitude': -74.00386306706551},
#  {'name': 'Tufino Pizzeria Napoletana',
#   'review_count': 450,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.773986,
#   'longitude': -73.908126},
#  {'name': 'Krispy Pizza',
#   'review_count': 246,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.713375,
#   'longitude': -74.035044},
#  {'name': "Philomena's",
#   'review_count': 160,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743264,
#   'longitude': -73.922928},
#  {'name': "Sal & Carmine's Pizza",
#   'review_count': 392,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7983115,
#   'longitude': -73.9694405},
#  {'name': 'House of Pizza & Calzones',
#   'review_count': 171,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.683944,
#   'longitude': -74.00225},
#  {'name': "Monte's Brick Oven",
#   'review_count': 171,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.807312,
#   'longitude': -73.926788},
#  {'name': 'Champion Pizza',
#   'review_count': 162,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.719742,
#   'longitude': -73.9872791},
#  {'name': 'Pier 76',
#   'review_count': 252,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.640118,
#   'longitude': -74.0759269},
#  {'name': 'Emily - West Village',
#   'review_count': 920,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.729375015649076,
#   'longitude': -74.00386306706551},
#  {'name': "Saba's Pizza",
#   'review_count': 119,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.78329,
#   'longitude': -73.978},
#  {'name': 'Krispy Pizza',
#   'review_count': 246,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.713375,
#   'longitude': -74.035044},
#  {'name': "Philomena's",
#   'review_count': 160,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743264,
#   'longitude': -73.922928},
#  {'name': "Sal & Carmine's Pizza",
#   'review_count': 392,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7983115,
#   'longitude': -73.9694405},
#  {'name': 'House of Pizza & Calzones',
#   'review_count': 171,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.683944,
#   'longitude': -74.00225},
#  {'name': "Monte's Brick Oven",
#   'review_count': 171,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.807312,
#   'longitude': -73.926788},
#  {'name': 'Champion Pizza',
#   'review_count': 162,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.719742,
#   'longitude': -73.9872791},
#  {'name': 'Pier 76',
#   'review_count': 252,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.640118,
#   'longitude': -74.0759269},
#  {'name': 'Rocco Pizza',
#   'review_count': 204,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.69224,
#   'longitude': -73.945849},
#  {'name': 'Sotto Le Stelle',
#   'review_count': 344,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743656,
#   'longitude': -73.9201782},
#  {'name': "Cecconi's Dumbo",
#   'review_count': 1008,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.7033063330116,
#   'longitude': -73.9916549604523},
#  {'name': "Frank's Pizza",
#   'review_count': 137,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.617634,
#   'longitude': -73.931864},
#  {'name': 'Sauce Pizzeria',
#   'review_count': 79,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7204894,
#   'longitude': -73.98927},
#  {'name': 'Da Gennaro',
#   'review_count': 1238,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.71832,
#   'longitude': -73.99794},
#  {'name': 'Pizzatown',
#   'review_count': 90,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.680043,
#   'longitude': -73.977872},
#  {'name': 'Margherita Pizza',
#   'review_count': 351,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7045845329735,
#   'longitude': -73.7967360578922},
#  {'name': 'Proto’s Pizza',
#   'review_count': 109,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.725353,
#   'longitude': -73.989746},
#  {'name': 'Coletta',
#   'review_count': 151,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.74094,
#   'longitude': -73.98139},
#  {'name': 'Upside Pizza',
#   'review_count': 44,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75157,
#   'longitude': -73.98059},
#  {'name': 'Bread and Salt',
#   'review_count': 148,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7435428136099,
#   'longitude': -74.0447338297963},
#  {'name': "Famous Ben's Pizza",
#   'review_count': 388,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7249388,
#   'longitude': -74.002451},
#  {'name': "L'Artusi",
#   'review_count': 2218,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73372,
#   'longitude': -74.00513},
#  {'name': "Julie's Pizzeria & Restaurant",
#   'review_count': 61,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.704239,
#   'longitude': -73.9072084},
#  {'name': "Pop's Pizzas",
#   'review_count': 130,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.767086,
#   'longitude': -73.983033},
#  {'name': 'Carranza Pizza',
#   'review_count': 9,
#   'rating': 2.5,
#   'price': '$',
#   'latitude': 40.669342,
#   'longitude': -73.896667},
#  {'name': 'Malaparte',
#   'review_count': 394,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73687,
#   'longitude': -74.00812},
#  {'name': 'Triangolo Pizza',
#   'review_count': 134,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.73357,
#   'longitude': -73.955116},
#  {'name': "Sofia's Pizza",
#   'review_count': 260,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.67751,
#   'longitude': -73.82586},
#  {'name': 'Battle Hill Tavern',
#   'review_count': 48,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.66023,
#   'longitude': -73.99135},
#  {'name': 'Brooklyn Pizza Market',
#   'review_count': 114,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.68273,
#   'longitude': -73.99305},
#  {'name': 'Barosa',
#   'review_count': 412,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.726197,
#   'longitude': -73.869795},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 1685,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.74406421842744,
#   'longitude': -74.00655890429283},
#  {'name': "Ciccio's Pizza",
#   'review_count': 130,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.596872,
#   'longitude': -73.976309},
#  {'name': "Jiannetto's Pizza Truck",
#   'review_count': 36,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.70525,
#   'longitude': -74.00675},
#  {'name': "Tony's Brick Oven",
#   'review_count': 117,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.615321,
#   'longitude': -74.067035},
#  {'name': "Rosa's Pizza",
#   'review_count': 310,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.712192,
#   'longitude': -73.899997},
#  {'name': 'Carbone',
#   'review_count': 1528,
#   'rating': 4.0,
#   'price': '$$$$',
#   'latitude': 40.728,
#   'longitude': -74.0001497},
#  {'name': "Elio's",
#   'review_count': 296,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.7767632368091,
#   'longitude': -73.9526632086427},
#  {'name': "Totonno's",
#   'review_count': 832,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.578913225666966,
#   'longitude': -73.98383392883555},
#  {'name': 'Zero Otto Nove',
#   'review_count': 523,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7407551035259,
#   'longitude': -73.9914887388588},
#  {'name': 'Clinton Square Pizza',
#   'review_count': 88,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71395,
#   'longitude': -73.98724},
#  {'name': 'Union Pizza Works',
#   'review_count': 288,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7073067,
#   'longitude': -73.922154},
#  {'name': "J's Pizza",
#   'review_count': 144,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7398164,
#   'longitude': -73.9989453},
#  {'name': 'Casa Theodoro',
#   'review_count': 134,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75693,
#   'longitude': -73.906747},
#  {'name': 'Stage Door Pizzeria',
#   'review_count': 289,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.712121,
#   'longitude': -74.009704},
#  {'name': 'La Villa Pizzeria & Restaurant',
#   'review_count': 323,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.61692,
#   'longitude': -73.9098},
#  {'name': 'Fumo',
#   'review_count': 200,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.80285617298625,
#   'longitude': -73.968119},
#  {'name': 'Pizza Wagon',
#   'review_count': 299,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.62129,
#   'longitude': -74.02659},
#  {'name': '21 Greenpoint',
#   'review_count': 129,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.72978,
#   'longitude': -73.95992},
#  {'name': 'Double Zero',
#   'review_count': 605,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7261288,
#   'longitude': -73.9896645},
#  {'name': "Vito's Slices and Ices",
#   'review_count': 261,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7545,
#   'longitude': -73.99528},
#  {'name': 'Enzo Bruni Pizza Gourmet',
#   'review_count': 96,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.783433,
#   'longitude': -73.947932},
#  {'name': "Sam's Pizza",
#   'review_count': 155,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.87939,
#   'longitude': -73.90601},
#  {'name': 'Aurora',
#   'review_count': 786,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.715621,
#   'longitude': -73.964757},
#  {'name': 'Piatto',
#   'review_count': 234,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7435117,
#   'longitude': -73.9590968},
#  {'name': "Beebe's",
#   'review_count': 165,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.754827,
#   'longitude': -73.935918},
#  {'name': 'Neapolitan Express',
#   'review_count': 6,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.77991,
#   'longitude': -73.9818},
#  {'name': 'Koronet Pizza',
#   'review_count': 671,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.8044212,
#   'longitude': -73.96610978649716},
#  {'name': 'Champion Pizza',
#   'review_count': 93,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.73592407559118,
#   'longitude': -73.99391475241151},
#  {'name': 'Pizza Rollio',
#   'review_count': 180,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.764259,
#   'longitude': -73.974552},
#  {'name': "Freddy's Pizzeria",
#   'review_count': 105,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.788956,
#   'longitude': -73.814049},
#  {'name': 'Singas Famous Pizza',
#   'review_count': 120,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.75416828100335,
#   'longitude': -73.82289803347588},
#  {'name': "Screamer's Pizzeria",
#   'review_count': 429,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7235518,
#   'longitude': -73.95065},
#  {'name': 'Pazza Notte',
#   'review_count': 988,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76348,
#   'longitude': -73.978091},
#  {'name': 'Da Nonna Rosa',
#   'review_count': 425,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.67291,
#   'longitude': -73.97697},
#  {'name': 'Luigi Pizza',
#   'review_count': 54,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.69006,
#   'longitude': -73.84071},
#  {'name': "Rocco's Pizzeria",
#   'review_count': 109,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.62692170776024,
#   'longitude': -74.023899},
#  {'name': 'Liberty Pizzeria',
#   'review_count': 43,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.693225,
#   'longitude': -73.966018},
#  {'name': 'Broadway Pizzeria',
#   'review_count': 126,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6933151509676,
#   'longitude': -73.9290830120444},
#  {'name': "Johnny's Pizzeria",
#   'review_count': 404,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.917609,
#   'longitude': -73.839425},
#  {'name': 'Lillian Pizzeria',
#   'review_count': 283,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7169776965988,
#   'longitude': -73.8522986602726},
#  {'name': "Rosario's",
#   'review_count': 185,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.77479,
#   'longitude': -73.91186},
#  {'name': 'Little Italy Pizza',
#   'review_count': 597,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.756482,
#   'longitude': -73.981484},
#  {'name': "Sal's Pizzeria",
#   'review_count': 222,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7904646826957,
#   'longitude': -74.0151917526793},
#  {'name': 'Pizza Plus',
#   'review_count': 271,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.66585,
#   'longitude': -73.98211},
#  {'name': "Victor's Pizzeria & Italian Restaurant",
#   'review_count': 190,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.8898885,
#   'longitude': -74.0248396},
#  {'name': "Corleone's Pizzeria",
#   'review_count': 249,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.86922,
#   'longitude': -74.07036},
#  {'name': 'Spunto',
#   'review_count': 466,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7297584,
#   'longitude': -74.0046303},
#  {'name': 'The Uptown Garrison',
#   'review_count': 182,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8512380090093,
#   'longitude': -73.9392676530849},
#  {'name': 'Bklyn Pizza',
#   'review_count': 169,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.68903,
#   'longitude': -73.92408},
#  {'name': "Percy's Pizza",
#   'review_count': 251,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.729076,
#   'longitude': -74.001534},
#  {'name': 'Table 87 - Gowanus',
#   'review_count': 413,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.670664,
#   'longitude': -73.991371},
#  {'name': "Renato's Pizza Masters",
#   'review_count': 460,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7442813,
#   'longitude': -74.0503861},
#  {'name': 'Mama Mia 44 SW',
#   'review_count': 823,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.759761,
#   'longitude': -73.992065},
#  {'name': 'Eleven B',
#   'review_count': 235,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.72745,
#   'longitude': -73.97974},
#  {'name': 'Centro Pizza Bar & Italian Kitchen',
#   'review_count': 204,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.74494463643489,
#   'longitude': -73.95312334111576},
#  {'name': "Denino's Pizzeria & Tavern",
#   'review_count': 904,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6302266718896,
#   'longitude': -74.1402754933448},
#  {'name': "Ovest Pizzoteca by Luzzo's",
#   'review_count': 591,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7507476806641,
#   'longitude': -74.0030212402344},
#  {'name': "Santillo's Brick Oven Pizza",
#   'review_count': 498,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6489921895261,
#   'longitude': -74.21664536653269},
#  {'name': 'Hatchets & Hops - Brooklyn Axe Throwing',
#   'review_count': 21,
#   'rating': 5.0,
#   'price': '$$$',
#   'latitude': 40.7212414,
#   'longitude': -73.95767370825116},
#  {'name': 'The Swiss Slice',
#   'review_count': 32,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.655633751718426,
#   'longitude': -73.9503288},
#  {'name': 'Marabella Pizza',
#   'review_count': 144,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7402335928167,
#   'longitude': -73.9238661770474},
#  {'name': "Carmine's Italian Restaurant - Times Square",
#   'review_count': 4374,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75749848725768,
#   'longitude': -73.98665333142026},
#  {'name': '&pizza - NoMad',
#   'review_count': 520,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.74520457937066,
#   'longitude': -73.98823142051697},
#  {'name': "Paul's On Times Square",
#   'review_count': 343,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75522,
#   'longitude': -73.98539},
#  {'name': 'La Casa Bella',
#   'review_count': 304,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.590666,
#   'longitude': -73.991456},
#  {'name': "Arturo's",
#   'review_count': 768,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.73039,
#   'longitude': -74.27802},
#  {'name': 'Sweetbriar',
#   'review_count': 54,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.7422837,
#   'longitude': -73.9831629},
#  {'name': "Rosella's Pizzeria",
#   'review_count': 269,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.710117,
#   'longitude': -74.005661},
#  {'name': 'Motorino',
#   'review_count': 280,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7855672,
#   'longitude': -73.9730817},
#  {'name': "Gaby's Pizza",
#   'review_count': 509,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.720562,
#   'longitude': -73.7609024},
#  {'name': 'Pizza Secret',
#   'review_count': 233,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6808,
#   'longitude': -73.97764},
#  {'name': 'Slice Pizza',
#   'review_count': 59,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75202,
#   'longitude': -73.97376},
#  {'name': "Roberta's Pizza",
#   'review_count': 246,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.754393,
#   'longitude': -73.976103},
#  {'name': "Joe & Pat's Pizzeria",
#   'review_count': 467,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.61281,
#   'longitude': -74.12198},
#  {'name': 'Piccola Strada',
#   'review_count': 227,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72662,
#   'longitude': -73.99019},
#  {'name': 'La Nonna Ristorante & Bar',
#   'review_count': 404,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.718468787527,
#   'longitude': -73.9639185527139},
#  {'name': "Martiniello's III",
#   'review_count': 23,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.682871137684,
#   'longitude': -73.8510749861598},
#  {'name': 'Underground Pizza',
#   'review_count': 329,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70499,
#   'longitude': -74.00961},
#  {'name': 'Blaze Pizza',
#   'review_count': 213,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7403059,
#   'longitude': -73.78695268},
#  {'name': "Armando's Pizza",
#   'review_count': 72,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6835403,
#   'longitude': -73.9111862},
#  {'name': 'Rooftop Reds',
#   'review_count': 169,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7025733903159,
#   'longitude': -73.9698984748688},
#  {'name': "Pugsley's Pizza",
#   'review_count': 180,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.85881,
#   'longitude': -73.88475},
#  {'name': 'S & S Calabro Pizzeria',
#   'review_count': 55,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.769171,
#   'longitude': -73.931012},
#  {'name': 'Pasta by Hudson',
#   'review_count': 101,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7427486,
#   'longitude': -73.9969892},
#  {'name': 'Royal Pizzeria Restaurant',
#   'review_count': 9,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.655174,
#   'longitude': -73.887446},
#  {'name': 'Napoli Wood Fired Pizza & Bakery',
#   'review_count': 235,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.82846,
#   'longitude': -73.98608},
#  {'name': "Bedstuy Mike's Pizza",
#   'review_count': 31,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6958847045898,
#   'longitude': -73.9465713500977},
#  {'name': 'Sacco Pizza',
#   'review_count': 447,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7662658691406,
#   'longitude': -73.9872665405273},
#  {'name': "Sal's Pizzeria",
#   'review_count': 55,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69276,
#   'longitude': -73.85883},
#  {'name': "Tony's Pizza",
#   'review_count': 52,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.664924,
#   'longitude': -73.923379},
#  {'name': 'Original Pizza',
#   'review_count': 82,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.63465,
#   'longitude': -74.0233},
#  {'name': 'La Vera Pizzeria',
#   'review_count': 66,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74067,
#   'longitude': -73.98218},
#  {'name': "Sicily's Best Pizzeria",
#   'review_count': 88,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.70517,
#   'longitude': -73.915155},
#  {'name': "Ganni's Pizza",
#   'review_count': 115,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.69419,
#   'longitude': -73.957809},
#  {'name': 'Cozzi Pizza',
#   'review_count': 39,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.70377,
#   'longitude': -73.94749},
#  {'name': 'Pomodoro Ristorante & Pizzeria',
#   'review_count': 218,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.79655,
#   'longitude': -74.47547},
#  {'name': 'A-1 Pizza Shop',
#   'review_count': 36,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.715061,
#   'longitude': -73.982355},
#  {'name': 'Shelter Pizza',
#   'review_count': 336,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.71967,
#   'longitude': -73.9608499},
#  {'name': 'Canal Pizza',
#   'review_count': 26,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7153479526233,
#   'longitude': -73.9934167353488},
#  {'name': 'Tenth Street Pasta & Pizza',
#   'review_count': 268,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.74935270874642,
#   'longitude': -74.03135923715374},
#  {'name': 'Mariella Pizza',
#   'review_count': 120,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.76920133403351,
#   'longitude': -73.9629409622093},
#  {'name': "Luzzo's Neapolitan Pizza & Wine Bar",
#   'review_count': 139,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7492468,
#   'longitude': -73.9420071},
#  {'name': "Ray's Pizza",
#   'review_count': 401,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7604321973079,
#   'longitude': -73.9839891042824},
#  {'name': 'Famous Famiglia Pizzeria',
#   'review_count': 99,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.778337,
#   'longitude': -73.956623},
#  {'name': 'Gotham West Market',
#   'review_count': 565,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7624395,
#   'longitude': -73.9971462},
#  {'name': 'IL FORNO A LEGNA',
#   'review_count': 330,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6064118,
#   'longitude': -74.2743223},
#  {'name': 'Tino’s Artisan Pizza',
#   'review_count': 104,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71416668884163,
#   'longitude': -74.03979259017832},
#  {'name': 'Armonie',
#   'review_count': 123,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.799791923483,
#   'longitude': -73.942575354665},
#  {'name': 'Amore Pizzeria',
#   'review_count': 544,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7693570273757,
#   'longitude': -73.8341404931405},
#  {'name': "Dante's Pizza",
#   'review_count': 164,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7101589996558,
#   'longitude': -73.8482174277306},
#  {'name': 'Highline Pizzeria',
#   'review_count': 177,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.751049,
#   'longitude': -74.0020523},
#  {'name': 'Cozzi Pizza',
#   'review_count': 39,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.70377,
#   'longitude': -73.94749},
#  {'name': 'Pomodoro Ristorante & Pizzeria',
#   'review_count': 218,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.79655,
#   'longitude': -74.47547},
#  {'name': 'A-1 Pizza Shop',
#   'review_count': 36,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.715061,
#   'longitude': -73.982355},
#  {'name': 'Shelter Pizza',
#   'review_count': 336,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.71967,
#   'longitude': -73.9608499},
#  {'name': 'Canal Pizza',
#   'review_count': 26,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7153479526233,
#   'longitude': -73.9934167353488},
#  {'name': "Mike's Pizza",
#   'review_count': 83,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.655368,
#   'longitude': -73.9565781},
#  {'name': 'Tenth Street Pasta & Pizza',
#   'review_count': 268,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.74935270874642,
#   'longitude': -74.03135923715374},
#  {'name': 'Mariella Pizza',
#   'review_count': 120,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.76920133403351,
#   'longitude': -73.9629409622093},
#  {'name': "Luzzo's Neapolitan Pizza & Wine Bar",
#   'review_count': 139,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7492468,
#   'longitude': -73.9420071},
#  {'name': "Mike's Pizza",
#   'review_count': 118,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7385362974077,
#   'longitude': -73.9806645185456},
#  {'name': "Ray's Pizza",
#   'review_count': 401,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7604321973079,
#   'longitude': -73.9839891042824},
#  {'name': 'Famous Famiglia Pizzeria',
#   'review_count': 99,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.778337,
#   'longitude': -73.956623},
#  {'name': 'Gotham West Market',
#   'review_count': 565,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7624395,
#   'longitude': -73.9971462},
#  {'name': 'Grace Pizza',
#   'review_count': 116,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70214,
#   'longitude': -73.8807999},
#  {'name': 'IL FORNO A LEGNA',
#   'review_count': 330,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6064118,
#   'longitude': -74.2743223},
#  {'name': 'Tino’s Artisan Pizza',
#   'review_count': 104,
#   'rating': 4.5,
#   'price': '$$',
# ...
#  {'name': 'VIPizza',
#   'review_count': 343,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7612782716751,
#   'longitude': -73.7699277698994},
#  {'name': 'Benito One',
#   'review_count': 804,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7200188460948,
#   'longitude': -73.9969412164592},
#  {'name': 'Garden Pizza',
#   'review_count': 120,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.81648,
#   'longitude': -74.00288},
#  {'name': 'Brothers Pizza',
#   'review_count': 61,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.66341,
#   'longitude': -73.99468},
#  {'name': 'The River Café',
#   'review_count': 1260,
#   'rating': 4.0,
#   'price': '$$$$',
#   'latitude': 40.703866713051106,
#   'longitude': -73.99479360219303},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 280,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7517,
#   'longitude': -73.97432},
#  {'name': 'Ozone Pizza',
#   'review_count': 129,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6808917,
#   'longitude': -73.8426307},
#  {'name': 'Nova Pizza & Pasta',
#   'review_count': 155,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.84919,
#   'longitude': -73.97083},
#  {'name': "Sticky's Finger Joint",
#   'review_count': 462,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74505372839559,
#   'longitude': -73.9788811},
#  {'name': 'Carve',
#   'review_count': 450,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7602042287575,
#   'longitude': -73.9873568460327},
#  {'name': 'The Smith',
#   'review_count': 2019,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7716201269986,
#   'longitude': -73.9818377981476},
#  {'name': "D'Angelo's Pizzeria & Restaurant",
#   'review_count': 23,
#   'rating': 2.5,
#   'price': '$$',
#   'latitude': 40.83059,
#   'longitude': -73.85687},
#  {'name': "Ferdinando's Focacceria",
#   'review_count': 214,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68418116575449,
#   'longitude': -74.0018677711487},
#  {'name': 'Amici Ristorante',
#   'review_count': 172,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71981,
#   'longitude': -73.99722},
#  {'name': "Luigi's Pizzeria of Mineola",
#   'review_count': 205,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74450383,
#   'longitude': -73.65620367},
#  {'name': 'Bravo Pizza',
#   'review_count': 129,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.73863,
#   'longitude': -73.98727},
#  {'name': 'Mama Rosa Cucina Pizzeria',
#   'review_count': 78,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.648513,
#   'longitude': -74.138297},
#  {'name': "Gnoccheria By Luzzo's",
#   'review_count': 509,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.723315,
#   'longitude': -73.983139},
#  {'name': 'Frankies 457 Spuntino',
#   'review_count': 881,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.677328,
#   'longitude': -73.997972},
#  {'name': 'The Elgin',
#   'review_count': 231,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.758194,
#   'longitude': -73.980905},
#  {'name': 'Da Nico Ristorante',
#   'review_count': 982,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.71963,
#   'longitude': -73.99691},
#  {'name': 'Italian Village Pizzeria',
#   'review_count': 255,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.771447,
#   'longitude': -73.952994},
#  {'name': 'Osteria 57',
#   'review_count': 291,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73467,
#   'longitude': -73.99786},
#  {'name': 'Via Vai',
#   'review_count': 242,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7741502,
#   'longitude': -73.9123089},
#  {'name': 'Damascus Bakery',
#   'review_count': 5,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70322,
#   'longitude': -73.98308},
#  {'name': "Rose's Pizzeria",
#   'review_count': 159,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.863583,
#   'longitude': -74.104848},
#  {'name': 'Brother’s Pizzeria',
#   'review_count': 275,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7398,
#   'longitude': -73.788972},
#  {'name': 'De Palma Pizzeria & Ristorante',
#   'review_count': 81,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.763534,
#   'longitude': -74.033157},
#  {'name': 'Little Italy Pizza',
#   'review_count': 172,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7502738,
#   'longitude': -73.9909354},
#  {'name': 'Panello',
#   'review_count': 217,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.747536,
#   'longitude': -74.037906},
#  {'name': 'Roma Pizzeria',
#   'review_count': 51,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.80816,
#   'longitude': -74.00796},
#  {'name': 'La Bella Pizza',
#   'review_count': 47,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6049099,
#   'longitude': -73.9977399},
#  {'name': 'La Scala Restaurant & Pizzeria',
#   'review_count': 286,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.815935283241,
#   'longitude': -73.291973754201},
#  {'name': "Manetta's Ristorante",
#   'review_count': 442,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7427,
#   'longitude': -73.95184},
#  {'name': 'Prime Pizza Kitchen',
#   'review_count': 67,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.5853249350922,
#   'longitude': -74.0926520634632},
#  {'name': "Romeo's Pizzeria",
#   'review_count': 97,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.681713,
#   'longitude': -73.83699},
#  {'name': 'Johnny Pepperoni',
#   'review_count': 394,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75011,
#   'longitude': -74.02969},
#  {'name': "Lenny's Pizza",
#   'review_count': 145,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74145,
#   'longitude': -73.92022},
#  {'name': 'Mulberry St. Pizza',
#   'review_count': 125,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7791410258621,
#   'longitude': -73.5295731686245},
#  {'name': '1653 Pizza Company',
#   'review_count': 76,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8716723,
#   'longitude': -73.4304367},
#  {'name': "Joe's Pizza",
#   'review_count': 29,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.83766,
#   'longitude': -73.86479},
#  {'name': 'Famous Famiglia Pizzeria ',
#   'review_count': 94,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.76569739383,
#   'longitude': -73.9573263022275},
#  {'name': 'Prima Pizza',
#   'review_count': 58,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6937218,
#   'longitude': -73.8527069},
#  {'name': 'Astoria Family Pizza',
#   'review_count': 64,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7808503,
#   'longitude': -73.9169041},
#  {'name': 'Sauce Pizzeria',
#   'review_count': 257,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73033,
#   'longitude': -73.98403},
#  {'name': 'Parm',
#   'review_count': 855,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.72303,
#   'longitude': -73.99567},
#  {'name': "Lee's Tavern",
#   'review_count': 616,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.588756,
#   'longitude': -74.095153},
#  {'name': "Patrizia's Of Maspeth",
#   'review_count': 256,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.726783,
#   'longitude': -73.894276},
#  {'name': 'Sorrento Pizzeria',
#   'review_count': 98,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.85447,
#   'longitude': -73.85438},
#  {'name': 'Yankee J-Z Pizza',
#   'review_count': 64,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.8292327076197,
#   'longitude': -73.8757006824017},
#  {'name': 'Mia Pizza',
#   'review_count': 130,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.77907,
#   'longitude': -73.91439},
#  {'name': "Brother's Pizzeria",
#   'review_count': 263,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.625598,
#   'longitude': -74.143835},
#  {'name': 'Porto Bello',
#   'review_count': 226,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.770352,
#   'longitude': -73.904303},
#  {'name': 'Lupa',
#   'review_count': 1708,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7276,
#   'longitude': -74.000045},
#  {'name': "The Original Sal's Pizza",
#   'review_count': 41,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.700424,
#   'longitude': -73.896354},
#  {'name': 'Sullivan Street Bakery',
#   'review_count': 544,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7473222,
#   'longitude': -74.0004691},
#  {'name': "Strawberry's Pub & Pizza",
#   'review_count': 380,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.5446448928292,
#   'longitude': -74.276500967984},
#  {'name': 'Low Fidelity',
#   'review_count': 173,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.73977,
#   'longitude': -74.04679},
#  {'name': 'Kiss My Slice',
#   'review_count': 262,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75576,
#   'longitude': -73.99052},
#  {'name': 'Beverley Pizza & Cafe',
#   'review_count': 129,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.64255,
#   'longitude': -73.97832},
#  {'name': 'Four Corners Pizza',
#   'review_count': 66,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.8960026,
#   'longitude': -73.8054674},
#  {'name': 'Gotham Pizza',
#   'review_count': 135,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.777568,
#   'longitude': -73.949218},
#  {'name': 'Ulivo',
#   'review_count': 365,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7447371960713,
#   'longitude': -73.9880339428782},
#  {'name': "Helen's Pizza",
#   'review_count': 192,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7212072,
#   'longitude': -74.0456498},
#  {'name': "Charlie's Pizzeria",
#   'review_count': 26,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6454519,
#   'longitude': -74.0101539},
#  {'name': 'Via Roma Pizza Bar',
#   'review_count': 60,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6780373,
#   'longitude': -73.9977648},
#  {'name': "Grimaldi's",
#   'review_count': 392,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.75453,
#   'longitude': -73.73854},
#  {'name': 'S. Egidio',
#   'review_count': 534,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.980227,
#   'longitude': -74.120093},
#  {'name': 'Anthony Francos Pizza - Fort Lee',
#   'review_count': 100,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.85118424054,
#   'longitude': -73.9690647558935},
#  {'name': 'Centre Pizzeria and Restaurant',
#   'review_count': 210,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.76447,
#   'longitude': -73.726049},
#  {'name': 'Enoteca Maria',
#   'review_count': 421,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.642,
#   'longitude': -74.07729},
#  {'name': "Joe's Pizza",
#   'review_count': 29,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.83766,
#   'longitude': -73.86479},
#  {'name': 'Famous Famiglia Pizzeria ',
#   'review_count': 94,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.76569739383,
#   'longitude': -73.9573263022275},
#  {'name': 'Astoria Family Pizza',
#   'review_count': 64,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7808503,
#   'longitude': -73.9169041},
#  {'name': 'Sauce Pizzeria',
#   'review_count': 257,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73033,
#   'longitude': -73.98403},
#  {'name': 'Parm',
#   'review_count': 855,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.72303,
#   'longitude': -73.99567},
#  {'name': "Lee's Tavern",
#   'review_count': 616,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.588756,
#   'longitude': -74.095153},
#  {'name': "Patrizia's Of Maspeth",
#   'review_count': 256,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.726783,
#   'longitude': -73.894276},
#  {'name': 'Sorrento Pizzeria',
#   'review_count': 98,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.85447,
#   'longitude': -73.85438},
#  {'name': 'Supper',
#   'review_count': 1455,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72290786539601,
#   'longitude': -73.98520720537888},
#  {'name': 'Yankee J-Z Pizza',
#   'review_count': 64,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.8292327076197,
#   'longitude': -73.8757006824017},
#  {'name': 'Mia Pizza',
#   'review_count': 130,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.77907,
#   'longitude': -73.91439},
#  {'name': "Brother's Pizzeria",
#   'review_count': 263,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.625598,
#   'longitude': -74.143835},
#  {'name': 'Porto Bello',
#   'review_count': 226,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.770352,
#   'longitude': -73.904303},
#  {'name': 'Franklin Pizza',
#   'review_count': 60,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.729684,
#   'longitude': -73.957827},
#  {'name': 'Lupa',
#   'review_count': 1708,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7276,
#   'longitude': -74.000045},
#  {'name': "The Original Sal's Pizza",
#   'review_count': 41,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.700424,
#   'longitude': -73.896354},
#  {'name': 'Sullivan Street Bakery',
#   'review_count': 544,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7473222,
#   'longitude': -74.0004691},
#  {'name': "Strawberry's Pub & Pizza",
#   'review_count': 380,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.5446448928292,
#   'longitude': -74.276500967984},
#  {'name': 'Low Fidelity',
#   'review_count': 173,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.73977,
#   'longitude': -74.04679},
#  {'name': 'Kiss My Slice',
#   'review_count': 262,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75576,
#   'longitude': -73.99052},
#  {'name': 'Beverley Pizza & Cafe',
#   'review_count': 129,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.64255,
#   'longitude': -73.97832},
#  {'name': 'Four Corners Pizza',
#   'review_count': 66,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.8960026,
#   'longitude': -73.8054674},
#  {'name': 'Gotham Pizza',
#   'review_count': 135,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.777568,
#   'longitude': -73.949218},
#  {'name': 'Ulivo',
#   'review_count': 365,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7447371960713,
#   'longitude': -73.9880339428782},
#  {'name': 'City Island Delicatessan',
#   'review_count': 4,
#   'rating': 5.0,
#   'price': '$',
#   'latitude': 40.85258,
#   'longitude': -73.789129},
#  {'name': "Helen's Pizza",
#   'review_count': 192,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7212072,
#   'longitude': -74.0456498},
#  {'name': 'Industry Kitchen',
#   'review_count': 880,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7049434740873,
#   'longitude': -74.0048825740814},
#  {'name': "Charlie's Pizzeria",
#   'review_count': 26,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6454519,
#   'longitude': -74.0101539},
#  {'name': 'Via Roma Pizza Bar',
#   'review_count': 60,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6780373,
#   'longitude': -73.9977648},
#  {'name': 'S. Egidio',
#   'review_count': 534,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.980227,
#   'longitude': -74.120093},
#  {'name': 'Centre Pizzeria and Restaurant',
#   'review_count': 210,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.76447,
#   'longitude': -73.726049},
#  {'name': "Marie's 2",
#   'review_count': 85,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.64224,
#   'longitude': -74.07674},
#  {'name': 'Taste of Tuscany',
#   'review_count': 99,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8568353549895,
#   'longitude': -74.0434074881405},
#  {'name': 'Famous Original Ray’s Pizza',
#   'review_count': 426,
#   'rating': 2.5,
#   'price': '$',
#   'latitude': 40.76038,
#   'longitude': -73.984},
#  {'name': 'Longo Bros',
#   'review_count': 66,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.754825,
#   'longitude': -73.994862},
#  {'name': 'Fiamma Wood Fired Pizza',
#   'review_count': 343,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6511098,
#   'longitude': -74.3478367},
#  {'name': 'Great Burrito',
#   'review_count': 266,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7428322,
#   'longitude': -73.9930115},
#  {'name': 'Basta Pasta',
#   'review_count': 1509,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73881,
#   'longitude': -73.99407},
#  {'name': 'The Pizza Place',
#   'review_count': 109,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.640716,
#   'longitude': -73.699516},
#  {'name': 'Scarpetta',
#   'review_count': 2200,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.744509,
#   'longitude': -73.9856},
#  {'name': 'A Pasta Bar',
#   'review_count': 460,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.72229,
#   'longitude': -74.00403},
#  {'name': "Fedoroff's Roast Pork",
#   'review_count': 350,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7189526,
#   'longitude': -73.9555245}]

# %%
# Replace None with appropriate code

# Import the library
import folium

# Set up center latitude and longitude
center_lat = full_dataset[0]['latitude']
center_long = full_dataset[0]['longitude']

# Initialize map with center lat and long
yelp_map = folium.Map([center_lat,center_long])

# Adjust this limit to see more or fewer businesses
limit=100

for business in full_dataset[:limit]:
    # Extract information about business
    lat = business['latitude']
    long = business['longitude']
    name = business['name']
    rating = business['rating']
    price = business['price']
    details = "{}\nPrice: {} Rating:{}".format(name,price,rating)
    
    # Create popup with relevant details
    popup = folium.Popup(details)
    
    # Create marker with relevant lat/long and popup
    marker = folium.Marker([lat,long],popup=popup)
    
    marker.add_to(yelp_map)
    
yelp_map
folium.
"""unlike 'Map; 'map are not callable. can't be used.***Mine"""
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you've made multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice interactive map to display the results using Folium! Well done!
